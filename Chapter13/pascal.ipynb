# %% [markdown]
# <a href="https://colab.research.google.com/github/usm-cos-432/InClass/blob/master/Chapter13/pascal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from fastai.vision import *

# %%
import fastai

# %% [markdown]
# ## Data

# %% [markdown]
# We are going to use the [Pascal dataset](http://host.robots.ox.ac.uk/pascal/VOC/) for object detection. There is a version from 2007 and a bigger version from 2012. We'll use the 2007 version here.

# %%
path = untar_data(URLs.PASCAL_2007, verbose=True)
# Out:
# Downloading https://s3.amazonaws.com/fast-ai-imagelocal/pascal_2007.tgz
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-9-6c0471089b9b> in <module>()
# ----> 1 path = untar_data(URLs.PASCAL_2007, verbose=True)
#
# /usr/local/lib/python3.6/dist-packages/fastai/datasets.py in untar_data(url, fname, dest, data, force_download, verbose)
#     233         fname = download_data(url, fname=fname, data=data)
#     234         if url in _checks:
# --> 235             assert _check_file(fname) == _checks[url], f"Downloaded file {fname} does not match checksum expected! Remove that file from {Config().data_archive_path()} and try your code again."
#     236         if verbose: print('.tgz file downloaded. Extracting the contents...')
#     237         tarfile.open(fname, 'r:gz').extractall(dest.parent)
#
# AssertionError: Downloaded file /root/.fastai/data/pascal_2007.tgz does not match checksum expected! Remove that file from /root/.fastai/data and try your code again.

# %%
# !tar xvfz /root/.fastai/data/pascal_2007.tgz
# Out:
# Streaming output truncated to the last 5000 lines.
# pascal_2007/train/008069.jpg
# pascal_2007/train/004499.jpg
# pascal_2007/train/004019.jpg
# pascal_2007/train/007621.jpg
# pascal_2007/train/006291.jpg
# pascal_2007/train/006141.jpg
# pascal_2007/train/002944.jpg
# pascal_2007/train/001494.jpg
# pascal_2007/train/000949.jpg
# pascal_2007/train/002320.jpg
# pascal_2007/train/009457.jpg
# pascal_2007/train/009904.jpg
# pascal_2007/train/006250.jpg
# pascal_2007/train/006161.jpg
# pascal_2007/train/004644.jpg
# pascal_2007/train/005365.jpg
# pascal_2007/train/009374.jpg
# pascal_2007/train/006260.jpg
# pascal_2007/train/008811.jpg
# pascal_2007/train/003331.jpg
# pascal_2007/train/004597.jpg
# pascal_2007/train/002481.jpg
# pascal_2007/train/002037.jpg
# pascal_2007/train/001650.jpg
# pascal_2007/train/004326.jpg
# pascal_2007/train/002735.jpg
# pascal_2007/train/002932.jpg
# pascal_2007/train/000443.jpg
# pascal_2007/train/005483.jpg
# pascal_2007/train/001309.jpg
# pascal_2007/train/008438.jpg
# pascal_2007/train/008514.jpg
# pascal_2007/train/004111.jpg
# pascal_2007/train/006444.jpg
# pascal_2007/train/009323.jpg
# pascal_2007/train/008263.jpg
# pascal_2007/train/003887.jpg
# pascal_2007/train/005417.jpg
# pascal_2007/train/007295.jpg
# pascal_2007/train/002181.jpg
# pascal_2007/train/002410.jpg
# pascal_2007/train/002873.jpg
# pascal_2007/train/006635.jpg
# pascal_2007/train/004113.jpg
# pascal_2007/train/003355.jpg
# pascal_2007/train/000251.jpg
# pascal_2007/train/005705.jpg
# pascal_2007/train/004517.jpg
# pascal_2007/train/006524.jpg
# pascal_2007/train/008635.jpg
# pascal_2007/train/000177.jpg
# pascal_2007/train/000438.jpg
# pascal_2007/train/007369.jpg
# pascal_2007/train/006235.jpg
# pascal_2007/train/004129.jpg
# pascal_2007/train/004601.jpg
# pascal_2007/train/007736.jpg
# pascal_2007/train/002836.jpg
# pascal_2007/train/001911.jpg
# pascal_2007/train/006484.jpg
# pascal_2007/train/007742.jpg
# pascal_2007/train/009349.jpg
# pascal_2007/train/009296.jpg
# pascal_2007/train/007546.jpg
# pascal_2007/train/004512.jpg
# pascal_2007/train/004455.jpg
# pascal_2007/train/006935.jpg
# pascal_2007/train/006989.jpg
# pascal_2007/train/004555.jpg
# pascal_2007/train/008833.jpg
# pascal_2007/train/009749.jpg
# pascal_2007/train/002710.jpg
# pascal_2007/train/009523.jpg
# pascal_2007/train/006836.jpg
# pascal_2007/train/007260.jpg
# pascal_2007/train/009108.jpg
# pascal_2007/train/007618.jpg
# pascal_2007/train/000895.jpg
# pascal_2007/train/004195.jpg
# pascal_2007/train/000129.jpg
# pascal_2007/train/003407.jpg
# pascal_2007/train/005509.jpg
# pascal_2007/train/006718.jpg
# pascal_2007/train/001463.jpg
# pascal_2007/train/007259.jpg
# pascal_2007/train/004345.jpg
# pascal_2007/train/003433.jpg
# pascal_2007/train/009291.jpg
# pascal_2007/train/003821.jpg
# pascal_2007/train/004812.jpg
# pascal_2007/train/001001.jpg
# pascal_2007/train/009586.jpg
# pascal_2007/train/003270.jpg
# pascal_2007/train/007215.jpg
# pascal_2007/train/003834.jpg
# pascal_2007/train/005305.jpg
# pascal_2007/train/003642.jpg
# pascal_2007/train/007979.jpg
# pascal_2007/train/005223.jpg
# pascal_2007/train/004912.jpg
# pascal_2007/train/000042.jpg
# pascal_2007/train/002774.jpg
# pascal_2007/train/003913.jpg
# pascal_2007/train/007694.jpg
# pascal_2007/train/003606.jpg
# pascal_2007/train/006916.jpg
# pascal_2007/train/005889.jpg
# pascal_2007/train/004961.jpg
# pascal_2007/train/000535.jpg
# pascal_2007/train/001350.jpg
# pascal_2007/train/004359.jpg
# pascal_2007/train/001294.jpg
# pascal_2007/train/002868.jpg
# pascal_2007/train/001002.jpg
# pascal_2007/train/009526.jpg
# pascal_2007/train/006120.jpg
# pascal_2007/train/001154.jpg
# pascal_2007/train/008494.jpg
# pascal_2007/train/006953.jpg
# pascal_2007/train/002542.jpg
# pascal_2007/train/001151.jpg
# pascal_2007/train/006661.jpg
# pascal_2007/train/006507.jpg
# pascal_2007/train/008224.jpg
# pascal_2007/train/005573.jpg
# pascal_2007/train/006272.jpg
# pascal_2007/train/001541.jpg
# pascal_2007/train/003915.jpg
# pascal_2007/train/000523.jpg
# pascal_2007/train/005615.jpg
# pascal_2007/train/009491.jpg
# pascal_2007/train/000034.jpg
# pascal_2007/train/005406.jpg
# pascal_2007/train/004936.jpg
# pascal_2007/train/008141.jpg
# pascal_2007/train/008813.jpg
# pascal_2007/train/007025.jpg
# pascal_2007/train/004085.jpg
# pascal_2007/train/003678.jpg
# pascal_2007/train/003103.jpg
# pascal_2007/train/009707.jpg
# pascal_2007/train/006486.jpg
# pascal_2007/train/000064.jpg
# pascal_2007/train/005146.jpg
# pascal_2007/train/009600.jpg
# pascal_2007/train/002096.jpg
# pascal_2007/train/008987.jpg
# pascal_2007/train/000827.jpg
# pascal_2007/train/006172.jpg
# pascal_2007/train/001160.jpg
# pascal_2007/train/001699.jpg
# pascal_2007/train/007481.jpg
# pascal_2007/train/003294.jpg
# pascal_2007/train/001388.jpg
# pascal_2007/train/008773.jpg
# pascal_2007/train/003077.jpg
# pascal_2007/train/000919.jpg
# pascal_2007/train/003441.jpg
# pascal_2007/train/005270.jpg
# pascal_2007/train/002472.jpg
# pascal_2007/train/003061.jpg
# pascal_2007/train/006706.jpg
# pascal_2007/train/005327.jpg
# pascal_2007/train/001254.jpg
# pascal_2007/train/001938.jpg
# pascal_2007/train/009246.jpg
# pascal_2007/train/009059.jpg
# pascal_2007/train/009917.jpg
# pascal_2007/train/001289.jpg
# pascal_2007/train/000989.jpg
# pascal_2007/train/007163.jpg
# pascal_2007/train/003034.jpg
# pascal_2007/train/003413.jpg
# pascal_2007/train/004544.jpg
# pascal_2007/train/006538.jpg
# pascal_2007/train/009698.jpg
# pascal_2007/train/008948.jpg
# pascal_2007/train/005230.jpg
# pascal_2007/train/006449.jpg
# pascal_2007/train/007256.jpg
# pascal_2007/train/008573.jpg
# pascal_2007/train/009434.jpg
# pascal_2007/train/006962.jpg
# pascal_2007/train/002697.jpg
# pascal_2007/train/004976.jpg
# pascal_2007/train/002270.jpg
# pascal_2007/train/005439.jpg
# pascal_2007/train/003465.jpg
# pascal_2007/train/005258.jpg
# pascal_2007/train/003369.jpg
# pascal_2007/train/003003.jpg
# pascal_2007/train/006281.jpg
# pascal_2007/train/007125.jpg
# pascal_2007/train/000304.jpg
# pascal_2007/train/001147.jpg
# pascal_2007/train/006827.jpg
# pascal_2007/train/001522.jpg
# pascal_2007/train/009407.jpg
# pascal_2007/train/009429.jpg
# pascal_2007/train/006349.jpg
# pascal_2007/train/005475.jpg
# pascal_2007/train/005395.jpg
# pascal_2007/train/002689.jpg
# pascal_2007/train/007864.jpg
# pascal_2007/train/005794.jpg
# pascal_2007/train/004902.jpg
# pascal_2007/train/005541.jpg
# pascal_2007/train/007943.jpg
# pascal_2007/train/005853.jpg
# pascal_2007/train/009543.jpg
# pascal_2007/train/006482.jpg
# pascal_2007/train/002666.jpg
# pascal_2007/train/007570.jpg
# pascal_2007/train/001636.jpg
# pascal_2007/train/001211.jpg
# pascal_2007/train/002070.jpg
# pascal_2007/train/006679.jpg
# pascal_2007/train/006759.jpg
# pascal_2007/train/003233.jpg
# pascal_2007/train/004715.jpg
# pascal_2007/train/001214.jpg
# pascal_2007/train/003891.jpg
# pascal_2007/train/001685.jpg
# pascal_2007/train/005806.jpg
# pascal_2007/train/002343.jpg
# pascal_2007/train/001259.jpg
# pascal_2007/train/003662.jpg
# pascal_2007/train/000215.jpg
# pascal_2007/train/008692.jpg
# pascal_2007/train/005379.jpg
# pascal_2007/train/002132.jpg
# pascal_2007/train/004563.jpg
# pascal_2007/train/001465.jpg
# pascal_2007/train/004929.jpg
# pascal_2007/train/001771.jpg
# pascal_2007/train/002718.jpg
# pascal_2007/train/009358.jpg
# pascal_2007/train/009295.jpg
# pascal_2007/train/000645.jpg
# pascal_2007/train/001488.jpg
# pascal_2007/train/008160.jpg
# pascal_2007/train/009868.jpg
# pascal_2007/train/009410.jpg
# pascal_2007/train/009022.jpg
# pascal_2007/train/000331.jpg
# pascal_2007/train/007795.jpg
# pascal_2007/train/009852.jpg
# pascal_2007/train/008695.jpg
# pascal_2007/train/009477.jpg
# pascal_2007/train/006565.jpg
# pascal_2007/train/009326.jpg
# pascal_2007/train/001323.jpg
# pascal_2007/train/004595.jpg
# pascal_2007/train/005554.jpg
# pascal_2007/train/006803.jpg
# pascal_2007/train/009692.jpg
# pascal_2007/train/009153.jpg
# pascal_2007/train/008095.jpg
# pascal_2007/train/007579.jpg
# pascal_2007/train/004841.jpg
# pascal_2007/train/000843.jpg
# pascal_2007/train/001346.jpg
# pascal_2007/train/006603.jpg
# pascal_2007/train/008973.jpg
# pascal_2007/train/006210.jpg
# pascal_2007/train/000694.jpg
# pascal_2007/train/007650.jpg
# pascal_2007/train/005664.jpg
# pascal_2007/train/007042.jpg
# pascal_2007/train/000850.jpg
# pascal_2007/train/000954.jpg
# pascal_2007/train/003628.jpg
# pascal_2007/train/001920.jpg
# pascal_2007/train/007146.jpg
# pascal_2007/train/002933.jpg
# pascal_2007/train/009116.jpg
# pascal_2007/train/006773.jpg
# pascal_2007/train/004951.jpg
# pascal_2007/train/008376.jpg
# pascal_2007/train/008519.jpg
# pascal_2007/train/003923.jpg
# pascal_2007/train/007946.jpg
# pascal_2007/train/002419.jpg
# pascal_2007/train/003667.jpg
# pascal_2007/train/008796.jpg
# pascal_2007/train/005175.jpg
# pascal_2007/train/003496.jpg
# pascal_2007/train/009717.jpg
# pascal_2007/train/003644.jpg
# pascal_2007/train/000246.jpg
# pascal_2007/train/005345.jpg
# pascal_2007/train/003752.jpg
# pascal_2007/train/006066.jpg
# pascal_2007/train/001840.jpg
# pascal_2007/train/000808.jpg
# pascal_2007/train/002916.jpg
# pascal_2007/train/009603.jpg
# pascal_2007/train/005868.jpg
# pascal_2007/train/002504.jpg
# pascal_2007/train/000936.jpg
# pascal_2007/train/002082.jpg
# pascal_2007/train/003947.jpg
# pascal_2007/train/003487.jpg
# pascal_2007/train/005153.jpg
# pascal_2007/train/005695.jpg
# pascal_2007/train/001683.jpg
# pascal_2007/train/000822.jpg
# pascal_2007/train/002494.jpg
# pascal_2007/train/002158.jpg
# pascal_2007/train/004972.jpg
# pascal_2007/train/004701.jpg
# pascal_2007/train/005676.jpg
# pascal_2007/train/007857.jpg
# pascal_2007/train/004794.jpg
# pascal_2007/train/004799.jpg
# pascal_2007/train/007325.jpg
# pascal_2007/train/006631.jpg
# pascal_2007/train/002126.jpg
# pascal_2007/train/002199.jpg
# pascal_2007/train/008048.jpg
# pascal_2007/train/005222.jpg
# pascal_2007/train/004808.jpg
# pascal_2007/train/009418.jpg
# pascal_2007/train/009794.jpg
# pascal_2007/train/008262.jpg
# pascal_2007/train/007775.jpg
# pascal_2007/train/000982.jpg
# pascal_2007/train/003236.jpg
# pascal_2007/train/002153.jpg
# pascal_2007/train/009136.jpg
# pascal_2007/train/001239.jpg
# pascal_2007/train/003122.jpg
# pascal_2007/train/006657.jpg
# pascal_2007/train/003363.jpg
# pascal_2007/train/007008.jpg
# pascal_2007/train/008351.jpg
# pascal_2007/train/006346.jpg
# pascal_2007/train/009945.jpg
# pascal_2007/train/007847.jpg
# pascal_2007/train/000632.jpg
# pascal_2007/train/009533.jpg
# pascal_2007/train/006874.jpg
# pascal_2007/train/008663.jpg
# pascal_2007/train/009713.jpg
# pascal_2007/train/003422.jpg
# pascal_2007/train/008557.jpg
# pascal_2007/train/009141.jpg
# pascal_2007/train/004058.jpg
# pascal_2007/train/000682.jpg
# pascal_2007/train/006668.jpg
# pascal_2007/train/001758.jpg
# pascal_2007/train/005398.jpg
# pascal_2007/train/002279.jpg
# pascal_2007/train/002880.jpg
# pascal_2007/train/000717.jpg
# pascal_2007/train/003444.jpg
# pascal_2007/train/009393.jpg
# pascal_2007/train/000592.jpg
# pascal_2007/train/006740.jpg
# pascal_2007/train/001324.jpg
# pascal_2007/train/001408.jpg
# pascal_2007/train/009036.jpg
# pascal_2007/train/004876.jpg
# pascal_2007/train/005530.jpg
# pascal_2007/train/009042.jpg
# pascal_2007/train/004796.jpg
# pascal_2007/train/002569.jpg
# pascal_2007/train/000613.jpg
# pascal_2007/train/005657.jpg
# pascal_2007/train/006781.jpg
# pascal_2007/train/004496.jpg
# pascal_2007/train/001543.jpg
# pascal_2007/train/006428.jpg
# pascal_2007/train/006140.jpg
# pascal_2007/train/009378.jpg
# pascal_2007/train/005368.jpg
# pascal_2007/train/001341.jpg
# pascal_2007/train/008776.jpg
# pascal_2007/train/006506.jpg
# pascal_2007/train/009470.jpg
# pascal_2007/train/001284.jpg
# pascal_2007/train/008346.jpg
# pascal_2007/train/003015.jpg
# pascal_2007/train/006030.jpg
# pascal_2007/train/005881.jpg
# pascal_2007/train/001915.jpg
# pascal_2007/train/009445.jpg
# pascal_2007/train/002896.jpg
# pascal_2007/train/008169.jpg
# pascal_2007/train/003990.jpg
# pascal_2007/train/001881.jpg
# pascal_2007/train/000306.jpg
# pascal_2007/train/002695.jpg
# pascal_2007/train/005214.jpg
# pascal_2007/train/001832.jpg
# pascal_2007/train/001759.jpg
# pascal_2007/train/007072.jpg
# pascal_2007/train/002001.jpg
# pascal_2007/train/000525.jpg
# pascal_2007/train/007803.jpg
# pascal_2007/train/008521.jpg
# pascal_2007/train/002779.jpg
# pascal_2007/train/004023.jpg
# pascal_2007/train/006727.jpg
# pascal_2007/train/005407.jpg
# pascal_2007/train/001298.jpg
# pascal_2007/train/009443.jpg
# pascal_2007/train/003898.jpg
# pascal_2007/train/001827.jpg
# pascal_2007/train/005297.jpg
# pascal_2007/train/000857.jpg
# pascal_2007/train/005027.jpg
# pascal_2007/train/007004.jpg
# pascal_2007/train/006797.jpg
# pascal_2007/train/000408.jpg
# pascal_2007/train/007296.jpg
# pascal_2007/train/003783.jpg
# pascal_2007/train/004368.jpg
# pascal_2007/train/005790.jpg
# pascal_2007/train/006828.jpg
# pascal_2007/train/001730.jpg
# pascal_2007/train/002054.jpg
# pascal_2007/train/002559.jpg
# pascal_2007/train/004998.jpg
# pascal_2007/train/008581.jpg
# pascal_2007/train/003360.jpg
# pascal_2007/train/000244.jpg
# pascal_2007/train/006950.jpg
# pascal_2007/train/002662.jpg
# pascal_2007/train/006995.jpg
# pascal_2007/train/008087.jpg
# pascal_2007/train/005923.jpg
# pascal_2007/train/003127.jpg
# pascal_2007/train/006450.jpg
# pascal_2007/train/007715.jpg
# pascal_2007/train/005761.jpg
# pascal_2007/train/007586.jpg
# pascal_2007/train/002267.jpg
# pascal_2007/train/005191.jpg
# pascal_2007/train/005496.jpg
# pascal_2007/train/005518.jpg
# pascal_2007/train/000431.jpg
# pascal_2007/train/001112.jpg
# pascal_2007/train/008063.jpg
# pascal_2007/train/002273.jpg
# pascal_2007/train/005861.jpg
# pascal_2007/train/009173.jpg
# pascal_2007/train/001161.jpg
# pascal_2007/train/002549.jpg
# pascal_2007/train/006660.jpg
# pascal_2007/train/009339.jpg
# pascal_2007/train/000829.jpg
# pascal_2007/train/005685.jpg
# pascal_2007/train/000007.jpg
# pascal_2007/train/008306.jpg
# pascal_2007/train/009955.jpg
# pascal_2007/train/005631.jpg
# pascal_2007/train/005497.jpg
# pascal_2007/train/002039.jpg
# pascal_2007/train/002375.jpg
# pascal_2007/train/001510.jpg
# pascal_2007/train/001809.jpg
# pascal_2007/train/007840.jpg
# pascal_2007/train/000131.jpg
# pascal_2007/train/008892.jpg
# pascal_2007/train/002163.jpg
# pascal_2007/train/007213.jpg
# pascal_2007/train/006131.jpg
# pascal_2007/train/006628.jpg
# pascal_2007/train/004171.jpg
# pascal_2007/train/009144.jpg
# pascal_2007/train/006862.jpg
# pascal_2007/train/009419.jpg
# pascal_2007/train/002368.jpg
# pascal_2007/train/004298.jpg
# pascal_2007/train/007410.jpg
# pascal_2007/train/008004.jpg
# pascal_2007/train/009954.jpg
# pascal_2007/train/002760.jpg
# pascal_2007/train/008890.jpg
# pascal_2007/train/003421.jpg
# pascal_2007/train/004647.jpg
# pascal_2007/train/008862.jpg
# pascal_2007/train/009961.jpg
# pascal_2007/train/005653.jpg
# pascal_2007/train/003296.jpg
# pascal_2007/train/009189.jpg
# pascal_2007/train/009089.jpg
# pascal_2007/train/005641.jpg
# pascal_2007/train/005065.jpg
# pascal_2007/train/006374.jpg
# pascal_2007/train/007873.jpg
# pascal_2007/train/007878.jpg
# pascal_2007/train/005954.jpg
# pascal_2007/train/006878.jpg
# pascal_2007/train/009098.jpg
# pascal_2007/train/005052.jpg
# pascal_2007/train/000848.jpg
# pascal_2007/train/005104.jpg
# pascal_2007/train/007141.jpg
# pascal_2007/train/009950.jpg
# pascal_2007/train/008091.jpg
# pascal_2007/train/008140.jpg
# pascal_2007/train/005729.jpg
# pascal_2007/train/002219.jpg
# pascal_2007/train/001775.jpg
# pascal_2007/train/005319.jpg
# pascal_2007/train/002578.jpg
# pascal_2007/train/005217.jpg
# pascal_2007/train/003292.jpg
# pascal_2007/train/003924.jpg
# pascal_2007/train/008374.jpg
# pascal_2007/train/001537.jpg
# pascal_2007/train/008513.jpg
# pascal_2007/train/008921.jpg
# pascal_2007/train/004542.jpg
# pascal_2007/train/001960.jpg
# pascal_2007/train/005829.jpg
# pascal_2007/train/005337.jpg
# pascal_2007/train/007740.jpg
# pascal_2007/train/008927.jpg
# pascal_2007/train/004046.jpg
# pascal_2007/train/002244.jpg
# pascal_2007/train/009347.jpg
# pascal_2007/train/006418.jpg
# pascal_2007/train/009342.jpg
# pascal_2007/train/004742.jpg
# pascal_2007/train/008506.jpg
# pascal_2007/train/008096.jpg
# pascal_2007/train/001364.jpg
# pascal_2007/train/008644.jpg
# pascal_2007/train/009644.jpg
# pascal_2007/train/007820.jpg
# pascal_2007/train/001287.jpg
# pascal_2007/train/002209.jpg
# pascal_2007/train/002465.jpg
# pascal_2007/train/002095.jpg
# pascal_2007/train/004867.jpg
# pascal_2007/train/006786.jpg
# pascal_2007/train/009016.jpg
# pascal_2007/train/008106.jpg
# pascal_2007/train/003509.jpg
# pascal_2007/train/007422.jpg
# pascal_2007/train/007551.jpg
# pascal_2007/train/000209.jpg
# pascal_2007/train/007677.jpg
# pascal_2007/train/001010.jpg
# pascal_2007/train/002179.jpg
# pascal_2007/train/007002.jpg
# pascal_2007/train/004673.jpg
# pascal_2007/train/005160.jpg
# pascal_2007/train/002975.jpg
# pascal_2007/train/006645.jpg
# pascal_2007/train/001962.jpg
# pascal_2007/train/003826.jpg
# pascal_2007/train/009087.jpg
# pascal_2007/train/005202.jpg
# pascal_2007/train/006632.jpg
# pascal_2007/train/007381.jpg
# pascal_2007/train/005682.jpg
# pascal_2007/train/000078.jpg
# pascal_2007/train/009252.jpg
# pascal_2007/train/009745.jpg
# pascal_2007/train/003424.jpg
# pascal_2007/train/001250.jpg
# pascal_2007/train/008197.jpg
# pascal_2007/train/000340.jpg
# pascal_2007/train/001999.jpg
# pascal_2007/train/009476.jpg
# pascal_2007/train/007968.jpg
# pascal_2007/train/009667.jpg
# pascal_2007/train/002056.jpg
# pascal_2007/train/002956.jpg
# pascal_2007/train/001878.jpg
# pascal_2007/train/001224.jpg
# pascal_2007/train/006519.jpg
# pascal_2007/train/008142.jpg
# pascal_2007/train/006769.jpg
# pascal_2007/train/007285.jpg
# pascal_2007/train/009242.jpg
# pascal_2007/train/004898.jpg
# pascal_2007/train/002519.jpg
# pascal_2007/train/003088.jpg
# pascal_2007/train/004307.jpg
# pascal_2007/train/000656.jpg
# pascal_2007/train/002523.jpg
# pascal_2007/train/006366.jpg
# pascal_2007/train/005813.jpg
# pascal_2007/train/002468.jpg
# pascal_2007/train/004295.jpg
# pascal_2007/train/003184.jpg
# pascal_2007/train/008403.jpg
# pascal_2007/train/002615.jpg
# pascal_2007/train/004735.jpg
# pascal_2007/train/005971.jpg
# pascal_2007/train/001517.jpg
# pascal_2007/train/000610.jpg
# pascal_2007/train/008450.jpg
# pascal_2007/train/000541.jpg
# pascal_2007/train/006363.jpg
# pascal_2007/train/006028.jpg
# pascal_2007/train/003074.jpg
# pascal_2007/train/006884.jpg
# pascal_2007/train/005387.jpg
# pascal_2007/train/000173.jpg
# pascal_2007/train/003537.jpg
# pascal_2007/train/005453.jpg
# pascal_2007/train/003461.jpg
# pascal_2007/train/001083.jpg
# pascal_2007/train/005901.jpg
# pascal_2007/train/004581.jpg
# pascal_2007/train/001466.jpg
# pascal_2007/train/003110.jpg
# pascal_2007/train/009862.jpg
# pascal_2007/train/009121.jpg
# pascal_2007/train/006483.jpg
# pascal_2007/train/002045.jpg
# pascal_2007/train/005854.jpg
# pascal_2007/train/006395.jpg
# pascal_2007/train/005521.jpg
# pascal_2007/train/000359.jpg
# pascal_2007/train/004387.jpg
# pascal_2007/train/002855.jpg
# pascal_2007/train/007152.jpg
# pascal_2007/train/002500.jpg
# pascal_2007/train/008036.jpg
# pascal_2007/train/005434.jpg
# pascal_2007/train/009666.jpg
# pascal_2007/train/002513.jpg
# pascal_2007/train/004549.jpg
# pascal_2007/train/009336.jpg
# pascal_2007/train/006282.jpg
# pascal_2007/train/006806.jpg
# pascal_2007/train/001468.jpg
# pascal_2007/train/008076.jpg
# pascal_2007/train/009636.jpg
# pascal_2007/train/005373.jpg
# pascal_2007/train/009557.jpg
# pascal_2007/train/008759.jpg
# pascal_2007/train/002518.jpg
# pascal_2007/train/008509.jpg
# pascal_2007/train/001653.jpg
# pascal_2007/train/000972.jpg
# pascal_2007/train/009597.jpg
# pascal_2007/train/000503.jpg
# pascal_2007/train/002420.jpg
# pascal_2007/train/000174.jpg
# pascal_2007/train/006670.jpg
# pascal_2007/train/001855.jpg
# pascal_2007/train/005268.jpg
# pascal_2007/train/005457.jpg
# pascal_2007/train/000117.jpg
# pascal_2007/train/008051.jpg
# pascal_2007/train/002190.jpg
# pascal_2007/train/005515.jpg
# pascal_2007/train/002667.jpg
# pascal_2007/train/001787.jpg
# pascal_2007/train/007210.jpg
# pascal_2007/train/003137.jpg
# pascal_2007/train/007261.jpg
# pascal_2007/train/002784.jpg
# pascal_2007/train/001870.jpg
# pascal_2007/train/008541.jpg
# pascal_2007/train/002371.jpg
# pascal_2007/train/001073.jpg
# pascal_2007/train/008572.jpg
# pascal_2007/train/001484.jpg
# pascal_2007/train/002815.jpg
# pascal_2007/train/006188.jpg
# pascal_2007/train/004840.jpg
# pascal_2007/train/005465.jpg
# pascal_2007/train/001152.jpg
# pascal_2007/train/001597.jpg
# pascal_2007/train/004365.jpg
# pascal_2007/train/009029.jpg
# pascal_2007/train/000577.jpg
# pascal_2007/train/004689.jpg
# pascal_2007/train/006474.jpg
# pascal_2007/train/008835.jpg
# pascal_2007/train/006799.jpg
# pascal_2007/train/009085.jpg
# pascal_2007/train/007513.jpg
# pascal_2007/train/009330.jpg
# pascal_2007/train/004997.jpg
# pascal_2007/train/006695.jpg
# pascal_2007/train/008433.jpg
# pascal_2007/train/005618.jpg
# pascal_2007/train/001404.jpg
# pascal_2007/train/008772.jpg
# pascal_2007/train/000289.jpg
# pascal_2007/train/003282.jpg
# pascal_2007/train/002745.jpg
# pascal_2007/train/007826.jpg
# pascal_2007/train/005020.jpg
# pascal_2007/train/004967.jpg
# pascal_2007/train/004710.jpg
# pascal_2007/train/000887.jpg
# pascal_2007/train/007475.jpg
# pascal_2007/train/008584.jpg
# pascal_2007/train/002859.jpg
# pascal_2007/train/005878.jpg
# pascal_2007/train/009596.jpg
# pascal_2007/train/002785.jpg
# pascal_2007/train/009032.jpg
# pascal_2007/train/003703.jpg
# pascal_2007/train/001445.jpg
# pascal_2007/train/001093.jpg
# pascal_2007/train/000400.jpg
# pascal_2007/train/003255.jpg
# pascal_2007/train/004753.jpg
# pascal_2007/train/007154.jpg
# pascal_2007/train/005029.jpg
# pascal_2007/train/009409.jpg
# pascal_2007/train/001079.jpg
# pascal_2007/train/000608.jpg
# pascal_2007/train/004587.jpg
# pascal_2007/train/007909.jpg
# pascal_2007/train/003086.jpg
# pascal_2007/train/003108.jpg
# pascal_2007/train/000394.jpg
# pascal_2007/train/005624.jpg
# pascal_2007/train/006602.jpg
# pascal_2007/train/009613.jpg
# pascal_2007/train/007177.jpg
# pascal_2007/train/006427.jpg
# pascal_2007/train/003163.jpg
# pascal_2007/train/002156.jpg
# pascal_2007/train/002525.jpg
# pascal_2007/train/009308.jpg
# pascal_2007/train/006943.jpg
# pascal_2007/train/002910.jpg
# pascal_2007/train/002810.jpg
# pascal_2007/train/002702.jpg
# pascal_2007/train/000764.jpg
# pascal_2007/train/000102.jpg
# pascal_2007/train/009460.jpg
# pascal_2007/train/008628.jpg
# pascal_2007/train/006128.jpg
# pascal_2007/train/008138.jpg
# pascal_2007/train/003194.jpg
# pascal_2007/train/000964.jpg
# pascal_2007/train/009123.jpg
# pascal_2007/train/007133.jpg
# pascal_2007/train/002025.jpg
# pascal_2007/train/006648.jpg
# pascal_2007/train/004315.jpg
# pascal_2007/train/005780.jpg
# pascal_2007/train/006216.jpg
# pascal_2007/train/009278.jpg
# pascal_2007/train/009481.jpg
# pascal_2007/train/003195.jpg
# pascal_2007/train/003451.jpg
# pascal_2007/train/004628.jpg
# pascal_2007/train/004777.jpg
# pascal_2007/train/005340.jpg
# pascal_2007/train/003963.jpg
# pascal_2007/train/001982.jpg
# pascal_2007/train/008200.jpg
# pascal_2007/train/003673.jpg
# pascal_2007/train/005393.jpg
# pascal_2007/train/006551.jpg
# pascal_2007/train/004012.jpg
# pascal_2007/train/000690.jpg
# pascal_2007/train/005131.jpg
# pascal_2007/train/002893.jpg
# pascal_2007/train/006233.jpg
# pascal_2007/train/003056.jpg
# pascal_2007/train/007292.jpg
# pascal_2007/train/003784.jpg
# pascal_2007/train/003154.jpg
# pascal_2007/train/005185.jpg
# pascal_2007/train/008748.jpg
# pascal_2007/train/002293.jpg
# pascal_2007/train/008108.jpg
# pascal_2007/train/004273.jpg
# pascal_2007/train/006805.jpg
# pascal_2007/train/004626.jpg
# pascal_2007/train/004020.jpg
# pascal_2007/train/003936.jpg
# pascal_2007/train/002599.jpg
# pascal_2007/train/003308.jpg
# pascal_2007/train/003349.jpg
# pascal_2007/train/009106.jpg
# pascal_2007/train/008534.jpg
# pascal_2007/train/009932.jpg
# pascal_2007/train/009605.jpg
# pascal_2007/train/008388.jpg
# pascal_2007/train/002268.jpg
# pascal_2007/train/001234.jpg
# pascal_2007/train/002036.jpg
# pascal_2007/train/003392.jpg
# pascal_2007/train/005662.jpg
# pascal_2007/train/000491.jpg
# pascal_2007/train/002722.jpg
# pascal_2007/train/004031.jpg
# pascal_2007/train/007841.jpg
# pascal_2007/train/002766.jpg
# pascal_2007/train/008979.jpg
# pascal_2007/train/001896.jpg
# pascal_2007/train/008019.jpg
# pascal_2007/train/005817.jpg
# pascal_2007/train/008815.jpg
# pascal_2007/train/007720.jpg
# pascal_2007/train/006088.jpg
# pascal_2007/train/007999.jpg
# pascal_2007/train/002194.jpg
# pascal_2007/train/004076.jpg
# pascal_2007/train/009629.jpg
# pascal_2007/train/007727.jpg
# pascal_2007/train/002088.jpg
# pascal_2007/train/002589.jpg
# pascal_2007/train/002492.jpg
# pascal_2007/train/003911.jpg
# pascal_2007/train/007933.jpg
# pascal_2007/train/002458.jpg
# pascal_2007/train/002478.jpg
# pascal_2007/train/009148.jpg
# pascal_2007/train/006658.jpg
# pascal_2007/train/004437.jpg
# pascal_2007/train/003645.jpg
# pascal_2007/train/007813.jpg
# pascal_2007/train/009184.jpg
# pascal_2007/train/006136.jpg
# pascal_2007/train/000755.jpg
# pascal_2007/train/000855.jpg
# pascal_2007/train/009466.jpg
# pascal_2007/train/004106.jpg
# pascal_2007/train/002935.jpg
# pascal_2007/train/002391.jpg
# pascal_2007/train/008859.jpg
# pascal_2007/train/007130.jpg
# pascal_2007/train/003705.jpg
# pascal_2007/train/009307.jpg
# pascal_2007/train/006694.jpg
# pascal_2007/train/008269.jpg
# pascal_2007/train/001200.jpg
# pascal_2007/train/007318.jpg
# pascal_2007/train/002572.jpg
# pascal_2007/train/000391.jpg
# pascal_2007/train/007445.jpg
# pascal_2007/train/008391.jpg
# pascal_2007/train/004916.jpg
# pascal_2007/train/008061.jpg
# pascal_2007/train/003688.jpg
# pascal_2007/train/000338.jpg
# pascal_2007/train/005212.jpg
# pascal_2007/train/009878.jpg
# pascal_2007/train/007815.jpg
# pascal_2007/train/003200.jpg
# pascal_2007/train/002436.jpg
# pascal_2007/train/006687.jpg
# pascal_2007/train/008279.jpg
# pascal_2007/train/004604.jpg
# pascal_2007/train/003970.jpg
# pascal_2007/train/006689.jpg
# pascal_2007/train/006438.jpg
# pascal_2007/train/000141.jpg
# pascal_2007/train/005423.jpg
# pascal_2007/train/009551.jpg
# pascal_2007/train/008841.jpg
# pascal_2007/train/004839.jpg
# pascal_2007/train/004856.jpg
# pascal_2007/train/002561.jpg
# pascal_2007/train/006201.jpg
# pascal_2007/train/003134.jpg
# pascal_2007/train/007831.jpg
# pascal_2007/train/004897.jpg
# pascal_2007/train/005674.jpg
# pascal_2007/train/001060.jpg
# pascal_2007/train/003941.jpg
# pascal_2007/train/004389.jpg
# pascal_2007/train/004470.jpg
# pascal_2007/train/003599.jpg
# pascal_2007/train/005073.jpg
# pascal_2007/train/001594.jpg
# pascal_2007/train/006196.jpg
# pascal_2007/train/001241.jpg
# pascal_2007/train/007356.jpg
# pascal_2007/train/007751.jpg
# pascal_2007/train/002545.jpg
# pascal_2007/train/002595.jpg
# pascal_2007/train/001316.jpg
# pascal_2007/train/003211.jpg
# pascal_2007/train/005033.jpg
# pascal_2007/train/001514.jpg
# pascal_2007/train/007498.jpg
# pascal_2007/train/000407.jpg
# pascal_2007/train/002782.jpg
# pascal_2007/train/000051.jpg
# pascal_2007/train/004367.jpg
# pascal_2007/train/009659.jpg
# pascal_2007/train/007705.jpg
# pascal_2007/train/007709.jpg
# pascal_2007/train/004066.jpg
# pascal_2007/train/000926.jpg
# pascal_2007/train/008955.jpg
# pascal_2007/train/004237.jpg
# pascal_2007/train/007479.jpg
# pascal_2007/train/005219.jpg
# pascal_2007/train/004013.jpg
# pascal_2007/train/000089.jpg
# pascal_2007/train/007877.jpg
# pascal_2007/train/003511.jpg
# pascal_2007/train/004346.jpg
# pascal_2007/train/003528.jpg
# pascal_2007/train/000198.jpg
# pascal_2007/train/008596.jpg
# pascal_2007/train/007439.jpg
# pascal_2007/train/000889.jpg
# pascal_2007/train/001528.jpg
# pascal_2007/train/001012.jpg
# pascal_2007/train/003098.jpg
# pascal_2007/train/006761.jpg
# pascal_2007/train/002906.jpg
# pascal_2007/train/008072.jpg
# pascal_2007/train/006971.jpg
# pascal_2007/train/002063.jpg
# pascal_2007/train/007624.jpg
# pascal_2007/train/006005.jpg
# pascal_2007/train/002051.jpg
# pascal_2007/train/000892.jpg
# pascal_2007/train/002374.jpg
# pascal_2007/train/006404.jpg
# pascal_2007/train/006190.jpg
# pascal_2007/train/006810.jpg
# pascal_2007/train/006398.jpg
# pascal_2007/train/005189.jpg
# pascal_2007/train/009580.jpg
# pascal_2007/train/002021.jpg
# pascal_2007/train/007184.jpg
# pascal_2007/train/005584.jpg
# pascal_2007/train/007223.jpg
# pascal_2007/train/001724.jpg
# pascal_2007/train/009816.jpg
# pascal_2007/train/002715.jpg
# pascal_2007/train/008495.jpg
# pascal_2007/train/002435.jpg
# pascal_2007/train/001385.jpg
# pascal_2007/train/008988.jpg
# pascal_2007/train/003244.jpg
# pascal_2007/train/006994.jpg
# pascal_2007/train/008997.jpg
# pascal_2007/train/000581.jpg
# pascal_2007/train/008638.jpg
# pascal_2007/train/004163.jpg
# pascal_2007/train/008260.jpg
# pascal_2007/train/002459.jpg
# pascal_2007/train/006536.jpg
# pascal_2007/train/001168.jpg
# pascal_2007/train/004283.jpg
# pascal_2007/train/002584.jpg
# pascal_2007/train/007615.jpg
# pascal_2007/train/009568.jpg
# pascal_2007/train/005590.jpg
# pascal_2007/train/008220.jpg
# pascal_2007/train/002524.jpg
# pascal_2007/train/005905.jpg
# pascal_2007/train/005264.jpg
# pascal_2007/train/003271.jpg
# pascal_2007/train/008624.jpg
# pascal_2007/train/008568.jpg
# pascal_2007/train/002942.jpg
# pascal_2007/train/007558.jpg
# pascal_2007/train/008483.jpg
# pascal_2007/train/009351.jpg
# pascal_2007/train/009282.jpg
# pascal_2007/train/008468.jpg
# pascal_2007/train/007436.jpg
# pascal_2007/train/008121.jpg
# pascal_2007/train/009461.jpg
# pascal_2007/train/003758.jpg
# pascal_2007/train/008174.jpg
# pascal_2007/train/004773.jpg
# pascal_2007/train/006012.jpg
# pascal_2007/train/000406.jpg
# pascal_2007/train/003996.jpg
# pascal_2007/train/001018.jpg
# pascal_2007/train/005304.jpg
# pascal_2007/train/002611.jpg
# pascal_2007/train/005588.jpg
# pascal_2007/train/004370.jpg
# pascal_2007/train/004526.jpg
# pascal_2007/train/006543.jpg
# pascal_2007/train/007424.jpg
# pascal_2007/train/006270.jpg
# pascal_2007/train/009619.jpg
# pascal_2007/train/003729.jpg
# pascal_2007/train/009863.jpg
# pascal_2007/train/003354.jpg
# pascal_2007/train/003250.jpg
# pascal_2007/train/004488.jpg
# pascal_2007/train/004003.jpg
# pascal_2007/train/003051.jpg
# pascal_2007/train/007538.jpg
# pascal_2007/train/004948.jpg
# pascal_2007/train/005058.jpg
# pascal_2007/train/007958.jpg
# pascal_2007/train/002901.jpg
# pascal_2007/train/000951.jpg
# pascal_2007/train/001633.jpg
# pascal_2007/train/001632.jpg
# pascal_2007/train/005451.jpg
# pascal_2007/train/003155.jpg
# pascal_2007/train/006958.jpg
# pascal_2007/train/003028.jpg
# pascal_2007/train/002134.jpg
# pascal_2007/train/005826.jpg
# pascal_2007/train/008144.jpg
# pascal_2007/train/006731.jpg
# pascal_2007/train/005644.jpg
# pascal_2007/train/000104.jpg
# pascal_2007/train/009464.jpg
# pascal_2007/train/006421.jpg
# pascal_2007/train/007219.jpg
# pascal_2007/train/008718.jpg
# pascal_2007/train/006794.jpg
# pascal_2007/train/008413.jpg
# pascal_2007/train/009063.jpg
# pascal_2007/train/009946.jpg
# pascal_2007/train/004148.jpg
# pascal_2007/train/009129.jpg
# pascal_2007/train/009463.jpg
# pascal_2007/train/005431.jpg
# pascal_2007/train/006852.jpg
# pascal_2007/train/004008.jpg
# pascal_2007/train/004987.jpg
# pascal_2007/train/002613.jpg
# pascal_2007/train/009155.jpg
# pascal_2007/train/006153.jpg
# pascal_2007/train/001400.jpg
# pascal_2007/train/002684.jpg
# pascal_2007/train/005239.jpg
# pascal_2007/train/000235.jpg
# pascal_2007/train/006976.jpg
# pascal_2007/train/005511.jpg
# pascal_2007/train/000552.jpg
# pascal_2007/train/007101.jpg
# pascal_2007/train/001922.jpg
# pascal_2007/train/000794.jpg
# pascal_2007/train/004025.jpg
# pascal_2007/train/007489.jpg
# pascal_2007/train/003519.jpg
# pascal_2007/train/002151.jpg
# pascal_2007/train/007890.jpg
# pascal_2007/train/004910.jpg
# pascal_2007/train/001481.jpg
# pascal_2007/train/008107.jpg
# pascal_2007/train/007132.jpg
# pascal_2007/train/000460.jpg
# pascal_2007/train/005818.jpg
# pascal_2007/train/008204.jpg
# pascal_2007/train/002635.jpg
# pascal_2007/train/002425.jpg
# pascal_2007/train/004950.jpg
# pascal_2007/train/004831.jpg
# pascal_2007/train/008930.jpg
# pascal_2007/train/003708.jpg
# pascal_2007/train/001137.jpg
# pascal_2007/train/009507.jpg
# pascal_2007/train/007679.jpg
# pascal_2007/train/008159.jpg
# pascal_2007/train/007519.jpg
# pascal_2007/train/001595.jpg
# pascal_2007/train/001907.jpg
# pascal_2007/train/008478.jpg
# pascal_2007/train/008462.jpg
# pascal_2007/train/004694.jpg
# pascal_2007/train/000035.jpg
# pascal_2007/train/006560.jpg
# pascal_2007/train/000387.jpg
# pascal_2007/train/006840.jpg
# pascal_2007/train/006860.jpg
# pascal_2007/train/004911.jpg
# pascal_2007/train/002321.jpg
# pascal_2007/train/008608.jpg
# pascal_2007/train/000800.jpg
# pascal_2007/train/000404.jpg
# pascal_2007/train/001311.jpg
# pascal_2007/train/005018.jpg
# pascal_2007/train/006103.jpg
# pascal_2007/train/006222.jpg
# pascal_2007/train/004498.jpg
# pascal_2007/train/001707.jpg
# pascal_2007/train/007663.jpg
# pascal_2007/train/009913.jpg
# pascal_2007/train/007314.jpg
# pascal_2007/train/004479.jpg
# pascal_2007/train/008858.jpg
# pascal_2007/train/004649.jpg
# pascal_2007/train/008753.jpg
# pascal_2007/train/009833.jpg
# pascal_2007/train/000214.jpg
# pascal_2007/train/005839.jpg
# pascal_2007/train/009288.jpg
# pascal_2007/train/007809.jpg
# pascal_2007/train/004520.jpg
# pascal_2007/train/006520.jpg
# pascal_2007/train/004551.jpg
# pascal_2007/train/005055.jpg
# pascal_2007/train/006933.jpg
# pascal_2007/train/002260.jpg
# pascal_2007/train/006357.jpg
# pascal_2007/train/002000.jpg
# pascal_2007/train/005991.jpg
# pascal_2007/train/004886.jpg
# pascal_2007/train/005253.jpg
# pascal_2007/train/008484.jpg
# pascal_2007/train/003905.jpg
# pascal_2007/train/002848.jpg
# pascal_2007/train/006329.jpg
# pascal_2007/train/000513.jpg
# pascal_2007/train/008397.jpg
# pascal_2007/train/009918.jpg
# pascal_2007/train/005718.jpg
# pascal_2007/train/008966.jpg
# pascal_2007/train/001539.jpg
# pascal_2007/train/000372.jpg
# pascal_2007/train/005658.jpg
# pascal_2007/train/000048.jpg
# pascal_2007/train/009823.jpg
# pascal_2007/train/005245.jpg
# pascal_2007/train/007791.jpg
# pascal_2007/train/001647.jpg
# pascal_2007/train/001078.jpg
# pascal_2007/train/005841.jpg
# pascal_2007/train/001199.jpg
# pascal_2007/train/002020.jpg
# pascal_2007/train/001066.jpg
# pascal_2007/train/002448.jpg
# pascal_2007/train/000163.jpg
# pascal_2007/train/003763.jpg
# pascal_2007/train/009923.jpg
# pascal_2007/train/006229.jpg
# pascal_2007/train/003469.jpg
# pascal_2007/train/007793.jpg
# pascal_2007/train/000763.jpg
# pascal_2007/train/005499.jpg
# pascal_2007/train/003064.jpg
# pascal_2007/train/007735.jpg
# pascal_2007/train/005908.jpg
# pascal_2007/train/000041.jpg
# pascal_2007/train/003709.jpg
# pascal_2007/train/001299.jpg
# pascal_2007/train/005315.jpg
# pascal_2007/train/008085.jpg
# pascal_2007/train/003320.jpg
# pascal_2007/train/007351.jpg
# pascal_2007/train/004145.jpg
# pascal_2007/train/003983.jpg
# pascal_2007/train/009094.jpg
# pascal_2007/train/000370.jpg
# pascal_2007/train/002817.jpg
# pascal_2007/train/005004.jpg
# pascal_2007/train/009566.jpg
# pascal_2007/train/006325.jpg
# pascal_2007/train/001544.jpg
# pascal_2007/train/007250.jpg
# pascal_2007/train/009181.jpg
# pascal_2007/train/005879.jpg
# pascal_2007/train/003714.jpg
# pascal_2007/train/001041.jpg
# pascal_2007/train/007090.jpg
# pascal_2007/train/002101.jpg
# pascal_2007/train/003374.jpg
# pascal_2007/train/003847.jpg
# pascal_2007/train/002043.jpg
# pascal_2007/train/004327.jpg
# pascal_2007/train/003658.jpg
# pascal_2007/train/007633.jpg
# pascal_2007/train/009762.jpg
# pascal_2007/train/002947.jpg
# pascal_2007/train/007204.jpg
# pascal_2007/train/009767.jpg
# pascal_2007/train/006135.jpg
# pascal_2007/train/007276.jpg
# pascal_2007/train/003835.jpg
# pascal_2007/train/007093.jpg
# pascal_2007/train/008564.jpg
# pascal_2007/train/001143.jpg
# pascal_2007/train/009540.jpg
# pascal_2007/train/003416.jpg
# pascal_2007/train/008423.jpg
# pascal_2007/train/009195.jpg
# pascal_2007/train/008416.jpg
# pascal_2007/train/005508.jpg
# pascal_2007/train/006944.jpg
# pascal_2007/train/006981.jpg
# pascal_2007/train/001821.jpg
# pascal_2007/train/008961.jpg
# pascal_2007/train/003004.jpg
# pascal_2007/train/005384.jpg
# pascal_2007/train/009179.jpg
# pascal_2007/train/000545.jpg
# pascal_2007/train/009585.jpg
# pascal_2007/train/009830.jpg
# pascal_2007/train/006117.jpg
# pascal_2007/train/005640.jpg
# pascal_2007/train/008595.jpg
# pascal_2007/train/009251.jpg
# pascal_2007/train/002024.jpg
# pascal_2007/train/002404.jpg
# pascal_2007/train/008607.jpg
# pascal_2007/train/000657.jpg
# pascal_2007/train/002191.jpg
# pascal_2007/train/002540.jpg
# pascal_2007/train/009438.jpg
# pascal_2007/train/009681.jpg
# pascal_2007/train/002302.jpg
# pascal_2007/train/003803.jpg
# pascal_2007/train/007685.jpg
# pascal_2007/train/004300.jpg
# pascal_2007/train/006130.jpg
# pascal_2007/train/001057.jpg
# pascal_2007/train/003063.jpg
# pascal_2007/train/009126.jpg
# pascal_2007/train/004532.jpg
# pascal_2007/train/004770.jpg
# pascal_2007/train/009200.jpg
# pascal_2007/train/002171.jpg
# pascal_2007/train/003189.jpg
# pascal_2007/train/000537.jpg
# pascal_2007/train/007244.jpg
# pascal_2007/train/007274.jpg
# pascal_2007/train/000605.jpg
# pascal_2007/train/004037.jpg
# pascal_2007/train/005274.jpg
# pascal_2007/train/004193.jpg
# pascal_2007/train/009177.jpg
# pascal_2007/train/000180.jpg
# pascal_2007/train/007059.jpg
# pascal_2007/train/007322.jpg
# pascal_2007/train/004600.jpg
# pascal_2007/train/009382.jpg
# pascal_2007/train/005756.jpg
# pascal_2007/train/003219.jpg
# pascal_2007/train/000486.jpg
# pascal_2007/train/005367.jpg
# pascal_2007/train/009279.jpg
# pascal_2007/train/004662.jpg
# pascal_2007/train/008151.jpg
# pascal_2007/train/003536.jpg
# pascal_2007/train/000635.jpg
# pascal_2007/train/005668.jpg
# pascal_2007/train/006911.jpg
# pascal_2007/train/007236.jpg
# pascal_2007/train/002355.jpg
# pascal_2007/train/009504.jpg
# pascal_2007/train/001756.jpg
# pascal_2007/train/005208.jpg
# pascal_2007/train/007435.jpg
# pascal_2007/train/009306.jpg
# pascal_2007/train/004170.jpg
# pascal_2007/train/006300.jpg
# pascal_2007/train/008253.jpg
# pascal_2007/train/006184.jpg
# pascal_2007/train/005995.jpg
# pascal_2007/train/001978.jpg
# pascal_2007/train/000036.jpg
# pascal_2007/train/003820.jpg
# pascal_2007/train/001293.jpg
# pascal_2007/train/008665.jpg
# pascal_2007/train/003450.jpg
# pascal_2007/train/004035.jpg
# pascal_2007/train/002786.jpg
# pascal_2007/train/009490.jpg
# pascal_2007/train/007691.jpg
# pascal_2007/train/007048.jpg
# pascal_2007/train/007073.jpg
# pascal_2007/train/000187.jpg
# pascal_2007/train/005992.jpg
# pascal_2007/train/008975.jpg
# pascal_2007/train/001170.jpg
# pascal_2007/train/003468.jpg
# pascal_2007/train/009289.jpg
# pascal_2007/train/003213.jpg
# pascal_2007/train/002585.jpg
# pascal_2007/train/009790.jpg
# pascal_2007/train/000285.jpg
# pascal_2007/train/002772.jpg
# pascal_2007/train/000589.jpg
# pascal_2007/train/003102.jpg
# pascal_2007/train/001761.jpg
# pascal_2007/train/009185.jpg
# pascal_2007/train/005899.jpg
# pascal_2007/train/000865.jpg
# pascal_2007/train/001348.jpg
# pascal_2007/train/009034.jpg
# pascal_2007/train/005363.jpg
# pascal_2007/train/001383.jpg
# pascal_2007/train/000222.jpg
# pascal_2007/train/003272.jpg
# pascal_2007/train/004612.jpg
# pascal_2007/train/005830.jpg
# pascal_2007/train/002401.jpg
# pascal_2007/train/000754.jpg
# pascal_2007/train/004060.jpg
# pascal_2007/train/004138.jpg
# pascal_2007/train/005988.jpg
# pascal_2007/train/004275.jpg
# pascal_2007/train/007568.jpg
# pascal_2007/train/000021.jpg
# pascal_2007/train/009007.jpg
# pascal_2007/train/008424.jpg
# pascal_2007/train/006371.jpg
# pascal_2007/train/004792.jpg
# pascal_2007/train/006105.jpg
# pascal_2007/train/008252.jpg
# pascal_2007/train/004205.jpg
# pascal_2007/train/003116.jpg
# pascal_2007/train/004873.jpg
# pascal_2007/train/003621.jpg
# pascal_2007/train/004229.jpg
# pascal_2007/train/006350.jpg
# pascal_2007/train/007763.jpg
# pascal_2007/train/006838.jpg
# pascal_2007/train/002533.jpg
# pascal_2007/train/004331.jpg
# pascal_2007/train/006939.jpg
# pascal_2007/train/003161.jpg
# pascal_2007/train/006158.jpg
# pascal_2007/train/001426.jpg
# pascal_2007/train/007003.jpg
# pascal_2007/train/003885.jpg
# pascal_2007/train/003588.jpg
# pascal_2007/train/009898.jpg
# pascal_2007/train/001192.jpg
# pascal_2007/train/000943.jpg
# pascal_2007/train/004768.jpg
# pascal_2007/train/000355.jpg
# pascal_2007/train/005629.jpg
# pascal_2007/train/009309.jpg
# pascal_2007/train/006234.jpg
# pascal_2007/train/008130.jpg
# pascal_2007/train/009131.jpg
# pascal_2007/train/003443.jpg
# pascal_2007/train/000381.jpg
# pascal_2007/train/006707.jpg
# pascal_2007/train/003042.jpg
# pascal_2007/train/007594.jpg
# pascal_2007/train/002939.jpg
# pascal_2007/train/009414.jpg
# pascal_2007/train/004849.jpg
# pascal_2007/train/008040.jpg
# pascal_2007/train/006107.jpg
# pascal_2007/train/005023.jpg
# pascal_2007/train/006829.jpg
# pascal_2007/train/008434.jpg
# pascal_2007/train/008985.jpg
# pascal_2007/train/005440.jpg
# pascal_2007/train/003735.jpg
# pascal_2007/train/008223.jpg
# pascal_2007/train/005947.jpg
# pascal_2007/train/007174.jpg
# pascal_2007/train/007092.jpg
# pascal_2007/train/003105.jpg
# pascal_2007/train/008320.jpg
# pascal_2007/train/008770.jpg
# pascal_2007/train/003410.jpg
# pascal_2007/train/004579.jpg
# pascal_2007/train/001555.jpg
# pascal_2007/train/005110.jpg
# pascal_2007/train/002820.jpg
# pascal_2007/train/008368.jpg
# pascal_2007/train/007859.jpg
# pascal_2007/train/001174.jpg
# pascal_2007/train/008978.jpg
# pascal_2007/train/007144.jpg
# pascal_2007/train/007191.jpg
# pascal_2007/train/005687.jpg
# pascal_2007/train/007468.jpg
# pascal_2007/train/007249.jpg
# pascal_2007/train/000900.jpg
# pascal_2007/train/001441.jpg
# pascal_2007/train/001932.jpg
# pascal_2007/train/002212.jpg
# pascal_2007/train/001690.jpg
# pascal_2007/train/007359.jpg
# pascal_2007/train/007062.jpg
# pascal_2007/train/006699.jpg
# pascal_2007/train/007642.jpg
# pascal_2007/train/008558.jpg
# pascal_2007/train/006866.jpg
# pascal_2007/train/005819.jpg
# pascal_2007/train/009112.jpg
# pascal_2007/train/002377.jpg
# pascal_2007/train/009446.jpg
# pascal_2007/train/001784.jpg
# pascal_2007/train/004034.jpg
# pascal_2007/train/004075.jpg
# pascal_2007/train/002385.jpg
# pascal_2007/train/003138.jpg
# pascal_2007/train/004606.jpg
# pascal_2007/train/003066.jpg
# pascal_2007/train/007612.jpg
# pascal_2007/train/006719.jpg
# pascal_2007/train/004890.jpg
# pascal_2007/train/002109.jpg
# pascal_2007/train/005912.jpg
# pascal_2007/train/002870.jpg
# pascal_2007/train/008699.jpg
# pascal_2007/train/005257.jpg
# pascal_2007/train/002310.jpg
# pascal_2007/train/004067.jpg
# pascal_2007/train/004656.jpg
# pascal_2007/train/003837.jpg
# pascal_2007/train/004281.jpg
# pascal_2007/train/004999.jpg
# pascal_2007/train/009417.jpg
# pascal_2007/train/000563.jpg
# pascal_2007/train/003660.jpg
# pascal_2007/train/003895.jpg
# pascal_2007/train/004223.jpg
# pascal_2007/train/005599.jpg
# pascal_2007/train/004785.jpg
# pascal_2007/train/005765.jpg
# pascal_2007/train/005680.jpg
# pascal_2007/train/000804.jpg
# pascal_2007/train/006055.jpg
# pascal_2007/train/003202.jpg
# pascal_2007/train/005424.jpg
# pascal_2007/train/004169.jpg
# pascal_2007/train/005199.jpg
# pascal_2007/train/004571.jpg
# pascal_2007/train/003546.jpg
# pascal_2007/train/004259.jpg
# pascal_2007/train/003713.jpg
# pascal_2007/train/004530.jpg
# pascal_2007/train/004869.jpg
# pascal_2007/train/003767.jpg
# pascal_2007/train/002842.jpg
# pascal_2007/train/005421.jpg
# pascal_2007/train/003178.jpg
# pascal_2007/train/003435.jpg
# pascal_2007/train/004687.jpg
# pascal_2007/train/002884.jpg
# pascal_2007/train/001651.jpg
# pascal_2007/train/006448.jpg
# pascal_2007/train/007511.jpg
# pascal_2007/train/008008.jpg
# pascal_2007/train/003664.jpg
# pascal_2007/train/009497.jpg
# pascal_2007/train/008880.jpg
# pascal_2007/train/008909.jpg
# pascal_2007/train/002064.jpg
# pascal_2007/train/003325.jpg
# pascal_2007/train/008470.jpg
# pascal_2007/train/008105.jpg
# pascal_2007/train/009099.jpg
# pascal_2007/train/000515.jpg
# pascal_2007/train/001571.jpg
# pascal_2007/train/008826.jpg
# pascal_2007/train/002423.jpg
# pascal_2007/train/005860.jpg
# pascal_2007/train/003239.jpg
# pascal_2007/train/000935.jpg
# pascal_2007/train/008372.jpg
# pascal_2007/train/007153.jpg
# pascal_2007/train/001203.jpg
# pascal_2007/train/004779.jpg
# pascal_2007/train/008261.jpg
# pascal_2007/train/005016.jpg
# pascal_2007/train/009488.jpg
# pascal_2007/train/000373.jpg
# pascal_2007/train/000112.jpg
# pascal_2007/train/004955.jpg
# pascal_2007/train/000676.jpg
# pascal_2007/train/000462.jpg
# pascal_2007/train/006825.jpg
# pascal_2007/train/002960.jpg
# pascal_2007/train/001588.jpg
# pascal_2007/train/000851.jpg
# pascal_2007/train/004232.jpg
# pascal_2007/train/006269.jpg
# pascal_2007/train/009359.jpg
# pascal_2007/train/007790.jpg
# pascal_2007/train/001717.jpg
# pascal_2007/train/001800.jpg
# pascal_2007/train/003949.jpg
# pascal_2007/train/005143.jpg
# pascal_2007/train/006611.jpg
# pascal_2007/train/005067.jpg
# pascal_2007/train/005328.jpg
# pascal_2007/train/006638.jpg
# pascal_2007/train/004623.jpg
# pascal_2007/train/002647.jpg
# pascal_2007/train/003997.jpg
# pascal_2007/train/004369.jpg
# pascal_2007/train/002869.jpg
# pascal_2007/train/003100.jpg
# pascal_2007/train/005875.jpg
# pascal_2007/train/000133.jpg
# pascal_2007/train/004333.jpg
# pascal_2007/train/005757.jpg
# pascal_2007/train/006802.jpg
# pascal_2007/train/007843.jpg
# pascal_2007/train/009627.jpg
# pascal_2007/train/001201.jpg
# pascal_2007/train/000063.jpg
# pascal_2007/train/007122.jpg
# pascal_2007/train/003629.jpg
# pascal_2007/train/003869.jpg
# pascal_2007/train/008043.jpg
# pascal_2007/train/009454.jpg
# pascal_2007/train/005968.jpg
# pascal_2007/train/003258.jpg
# pascal_2007/train/000672.jpg
# pascal_2007/train/001638.jpg
# pascal_2007/train/001617.jpg
# pascal_2007/train/005894.jpg
# pascal_2007/train/007517.jpg
# pascal_2007/train/009905.jpg
# pascal_2007/train/006309.jpg
# pascal_2007/train/007105.jpg
# pascal_2007/train/002444.jpg
# pascal_2007/train/004837.jpg
# pascal_2007/train/006098.jpg
# pascal_2007/train/002763.jpg
# pascal_2007/train/002816.jpg
# pascal_2007/train/003567.jpg
# pascal_2007/train/007683.jpg
# pascal_2007/train/006697.jpg
# pascal_2007/train/007451.jpg
# pascal_2007/train/001640.jpg
# pascal_2007/train/004743.jpg
# pascal_2007/train/009959.jpg
# pascal_2007/train/003419.jpg
# pascal_2007/train/005606.jpg
# pascal_2007/train/003960.jpg
# pascal_2007/train/000993.jpg
# pascal_2007/train/008602.jpg
# pascal_2007/train/000232.jpg
# pascal_2007/train/005338.jpg
# pascal_2007/train/000911.jpg
# pascal_2007/train/004591.jpg
# pascal_2007/train/001397.jpg
# pascal_2007/train/006684.jpg
# pascal_2007/train/002886.jpg
# pascal_2007/train/003452.jpg
# pascal_2007/train/000017.jpg
# pascal_2007/train/009611.jpg
# pascal_2007/train/007655.jpg
# pascal_2007/train/004292.jpg
# pascal_2007/train/001523.jpg
# pascal_2007/train/004574.jpg
# pascal_2007/train/009333.jpg
# pascal_2007/train/003300.jpg
# pascal_2007/train/002460.jpg
# pascal_2007/train/004960.jpg
# pascal_2007/train/007185.jpg
# pascal_2007/train/006637.jpg
# pascal_2007/train/003845.jpg
# pascal_2007/train/005702.jpg
# pascal_2007/train/000352.jpg
# pascal_2007/train/002899.jpg
# pascal_2007/train/002335.jpg
# pascal_2007/train/002633.jpg
# pascal_2007/train/006447.jpg
# pascal_2007/train/005715.jpg
# pascal_2007/train/000266.jpg
# pascal_2007/train/000902.jpg
# pascal_2007/train/006965.jpg
# pascal_2007/train/009312.jpg
# pascal_2007/train/002288.jpg
# pascal_2007/train/006880.jpg
# pascal_2007/train/005831.jpg
# pascal_2007/train/009809.jpg
# pascal_2007/train/005001.jpg
# pascal_2007/train/001119.jpg
# pascal_2007/train/007914.jpg
# pascal_2007/train/009637.jpg
# pascal_2007/train/005269.jpg
# pascal_2007/train/008752.jpg
# pascal_2007/train/005773.jpg
# pascal_2007/train/002734.jpg
# pascal_2007/train/005961.jpg
# pascal_2007/train/008188.jpg
# pascal_2007/train/006067.jpg
# pascal_2007/train/003539.jpg
# pascal_2007/train/006900.jpg
# pascal_2007/train/008653.jpg
# pascal_2007/train/007086.jpg
# pascal_2007/train/003876.jpg
# pascal_2007/train/007923.jpg
# pascal_2007/train/001279.jpg
# pascal_2007/train/003760.jpg
# pascal_2007/train/001795.jpg
# pascal_2007/train/003356.jpg
# pascal_2007/train/002767.jpg
# pascal_2007/train/001686.jpg
# pascal_2007/train/008009.jpg
# pascal_2007/train/004204.jpg
# pascal_2007/train/008295.jpg
# pascal_2007/train/009549.jpg
# pascal_2007/train/001145.jpg
# pascal_2007/train/003162.jpg
# pascal_2007/train/007746.jpg
# pascal_2007/train/008317.jpg
# pascal_2007/train/005524.jpg
# pascal_2007/train/003093.jpg
# pascal_2007/train/009848.jpg
# pascal_2007/train/001497.jpg
# pascal_2007/train/000796.jpg
# pascal_2007/train/001077.jpg
# pascal_2007/train/007872.jpg
# pascal_2007/train/002992.jpg
# pascal_2007/train/002411.jpg
# pascal_2007/train/009465.jpg
# pascal_2007/train/002174.jpg
# pascal_2007/train/006893.jpg
# pascal_2007/train/002727.jpg
# pascal_2007/train/006062.jpg
# pascal_2007/train/009702.jpg
# pascal_2007/train/007036.jpg
# pascal_2007/train/009686.jpg
# pascal_2007/train/006095.jpg
# pascal_2007/train/007095.jpg
# pascal_2007/train/007821.jpg
# pascal_2007/train/002108.jpg
# pascal_2007/train/009394.jpg
# pascal_2007/train/000849.jpg
# pascal_2007/train/004102.jpg
# pascal_2007/train/009647.jpg
# pascal_2007/train/009448.jpg
# pascal_2007/train/008001.jpg
# pascal_2007/train/004592.jpg
# pascal_2007/train/007323.jpg
# pascal_2007/train/001221.jpg
# pascal_2007/train/007070.jpg
# pascal_2007/train/002571.jpg
# pascal_2007/train/007776.jpg
# pascal_2007/train/007779.jpg
# pascal_2007/train/000208.jpg
# pascal_2007/train/005097.jpg
# pascal_2007/train/001954.jpg
# pascal_2007/train/007959.jpg
# pascal_2007/train/008475.jpg
# pascal_2007/train/008559.jpg
# pascal_2007/train/009086.jpg
# pascal_2007/train/000170.jpg
# pascal_2007/train/007035.jpg
# pascal_2007/train/001971.jpg
# pascal_2007/train/009944.jpg
# pascal_2007/train/002340.jpg
# pascal_2007/train/002323.jpg
# pascal_2007/train/008199.jpg
# pascal_2007/train/006497.jpg
# pascal_2007/train/007724.jpg
# pascal_2007/train/001008.jpg
# pascal_2007/train/004092.jpg
# pascal_2007/train/006304.jpg
# pascal_2007/train/005068.jpg
# pascal_2007/train/002544.jpg
# pascal_2007/train/002801.jpg
# ...
# pascal_2007/train/000867.jpg
# pascal_2007/train/000153.jpg
# pascal_2007/train/003327.jpg
# pascal_2007/train/004284.jpg
# pascal_2007/train/007330.jpg
# pascal_2007/train/002337.jpg
# pascal_2007/train/003240.jpg
# pascal_2007/train/006459.jpg
# pascal_2007/train/007100.jpg
# pascal_2007/train/001801.jpg
# pascal_2007/train/004409.jpg
# pascal_2007/train/005824.jpg
# pascal_2007/train/007167.jpg
# pascal_2007/train/009186.jpg
# pascal_2007/train/000050.jpg
# pascal_2007/train/005481.jpg
# pascal_2007/train/005948.jpg
# pascal_2007/train/000066.jpg
# pascal_2007/train/003008.jpg
# pascal_2007/train/003293.jpg
# pascal_2007/train/001028.jpg
# pascal_2007/train/004474.jpg
# pascal_2007/train/009758.jpg
# pascal_2007/train/000782.jpg
# pascal_2007/train/008523.jpg
# pascal_2007/train/008430.jpg
# pascal_2007/train/006240.jpg
# pascal_2007/train/004016.jpg
# pascal_2007/train/001444.jpg
# pascal_2007/train/008688.jpg
# pascal_2007/train/008911.jpg
# pascal_2007/train/004110.jpg
# pascal_2007/train/003518.jpg
# pascal_2007/train/002228.jpg
# pascal_2007/train/004634.jpg
# pascal_2007/train/009908.jpg
# pascal_2007/train/000065.jpg
# pascal_2007/train/004973.jpg
# pascal_2007/train/002675.jpg
# pascal_2007/train/000921.jpg
# pascal_2007/train/009801.jpg
# pascal_2007/train/008492.jpg
# pascal_2007/train/001521.jpg
# pascal_2007/train/000637.jpg
# pascal_2007/train/007940.jpg
# pascal_2007/train/004982.jpg
# pascal_2007/train/000599.jpg
# pascal_2007/train/007925.jpg
# pascal_2007/train/009168.jpg
# pascal_2007/train/009060.jpg
# pascal_2007/train/005420.jpg
# pascal_2007/train/006678.jpg
# pascal_2007/train/002677.jpg
# pascal_2007/train/006887.jpg
# pascal_2007/train/008749.jpg
# pascal_2007/train/009733.jpg
# pascal_2007/train/007540.jpg
# pascal_2007/train/002757.jpg
# pascal_2007/train/004566.jpg
# pascal_2007/train/009105.jpg
# pascal_2007/train/002102.jpg
# pascal_2007/train/009458.jpg
# pascal_2007/train/004131.jpg
# pascal_2007/train/005298.jpg
# pascal_2007/train/008209.jpg
# pascal_2007/train/007682.jpg
# pascal_2007/train/005951.jpg
# pascal_2007/train/008042.jpg
# pascal_2007/train/008760.jpg
# pascal_2007/train/001265.jpg
# pascal_2007/train/001113.jpg
# pascal_2007/train/003090.jpg
# pascal_2007/train/006625.jpg
# pascal_2007/train/007461.jpg
# pascal_2007/train/006868.jpg
# pascal_2007/train/003425.jpg
# pascal_2007/train/000446.jpg
# pascal_2007/train/002433.jpg
# pascal_2007/train/006189.jpg
# pascal_2007/train/006419.jpg
# pascal_2007/train/007413.jpg
# pascal_2007/train/002847.jpg
# pascal_2007/train/003330.jpg
# pascal_2007/train/000500.jpg
# pascal_2007/train/006473.jpg
# pascal_2007/train/009005.jpg
# pascal_2007/train/006855.jpg
# pascal_2007/train/000625.jpg
# pascal_2007/train/007920.jpg
# pascal_2007/train/008293.jpg
# pascal_2007/train/000328.jpg
# pascal_2007/train/000464.jpg
# pascal_2007/train/003984.jpg
# pascal_2007/train/001395.jpg
# pascal_2007/train/008203.jpg
# pascal_2007/train/006061.jpg
# pascal_2007/train/005539.jpg
# pascal_2007/train/000138.jpg
# pascal_2007/train/002546.jpg
# pascal_2007/train/004671.jpg
# pascal_2007/train/003992.jpg
# pascal_2007/train/001577.jpg
# pascal_2007/train/007114.jpg
# pascal_2007/train/003007.jpg
# pascal_2007/train/009433.jpg
# pascal_2007/train/001043.jpg
# pascal_2007/train/009371.jpg
# pascal_2007/train/005821.jpg
# pascal_2007/train/005591.jpg
# pascal_2007/train/005956.jpg
# pascal_2007/train/002350.jpg
# pascal_2007/train/002248.jpg
# pascal_2007/train/008529.jpg
# pascal_2007/train/001845.jpg
# pascal_2007/train/005918.jpg
# pascal_2007/train/009920.jpg
# pascal_2007/train/000756.jpg
# pascal_2007/train/005864.jpg
# pascal_2007/train/003118.jpg
# pascal_2007/train/002197.jpg
# pascal_2007/train/001768.jpg
# pascal_2007/train/003261.jpg
# pascal_2007/train/006306.jpg
# pascal_2007/train/008335.jpg
# pascal_2007/train/005701.jpg
# pascal_2007/train/000171.jpg
# pascal_2007/train/008381.jpg
# pascal_2007/train/001934.jpg
# pascal_2007/train/005071.jpg
# pascal_2007/train/007483.jpg
# pascal_2007/train/006041.jpg
# pascal_2007/train/008731.jpg
# pascal_2007/train/009676.jpg
# pascal_2007/train/003530.jpg
# pascal_2007/train/001171.jpg
# pascal_2007/train/006335.jpg
# pascal_2007/train/002490.jpg
# pascal_2007/train/003625.jpg
# pascal_2007/train/003699.jpg
# pascal_2007/train/006918.jpg
# pascal_2007/train/004361.jpg
# pascal_2007/train/008083.jpg
# pascal_2007/train/005574.jpg
# pascal_2007/train/006338.jpg
# pascal_2007/train/008867.jpg
# pascal_2007/train/001386.jpg
# pascal_2007/train/007865.jpg
# pascal_2007/train/005290.jpg
# pascal_2007/train/008932.jpg
# pascal_2007/train/001877.jpg
# pascal_2007/train/009500.jpg
# pascal_2007/train/004140.jpg
# pascal_2007/train/008936.jpg
# pascal_2007/train/002266.jpg
# pascal_2007/train/008222.jpg
# pascal_2007/train/003844.jpg
# pascal_2007/train/004938.jpg
# pascal_2007/train/008442.jpg
# pascal_2007/train/002924.jpg
# pascal_2007/train/002022.jpg
# pascal_2007/train/000619.jpg
# pascal_2007/train/000898.jpg
# pascal_2007/train/004404.jpg
# pascal_2007/train/001892.jpg
# pascal_2007/train/004846.jpg
# pascal_2007/train/000966.jpg
# pascal_2007/train/006247.jpg
# pascal_2007/train/004286.jpg
# pascal_2007/train/004685.jpg
# pascal_2007/train/007976.jpg
# pascal_2007/train/001610.jpg
# pascal_2007/train/001677.jpg
# pascal_2007/train/003391.jpg
# pascal_2007/train/001004.jpg
# pascal_2007/train/000667.jpg
# pascal_2007/train/001205.jpg
# pascal_2007/train/002415.jpg
# pascal_2007/train/002867.jpg
# pascal_2007/train/008620.jpg
# pascal_2007/train/002186.jpg
# pascal_2007/train/001310.jpg
# pascal_2007/train/004896.jpg
# pascal_2007/train/001940.jpg
# pascal_2007/train/000550.jpg
# pascal_2007/train/009865.jpg
# pascal_2007/train/008191.jpg
# pascal_2007/train/008819.jpg
# pascal_2007/train/008275.jpg
# pascal_2007/train/003408.jpg
# pascal_2007/train/000024.jpg
# pascal_2007/train/004247.jpg
# pascal_2007/train/007901.jpg
# pascal_2007/train/002136.jpg
# pascal_2007/train/000767.jpg
# pascal_2007/train/001785.jpg
# pascal_2007/train/000720.jpg
# pascal_2007/train/009508.jpg
# pascal_2007/train/008415.jpg
# pascal_2007/train/001045.jpg
# pascal_2007/train/000121.jpg
# pascal_2007/train/004954.jpg
# pascal_2007/train/006382.jpg
# pascal_2007/train/008338.jpg
# pascal_2007/train/005704.jpg
# pascal_2007/train/003210.jpg
# pascal_2007/train/002140.jpg
# pascal_2007/train/007437.jpg
# pascal_2007/train/004349.jpg
# pascal_2007/train/005006.jpg
# pascal_2007/train/004174.jpg
# pascal_2007/train/000091.jpg
# pascal_2007/train/004507.jpg
# pascal_2007/train/000450.jpg
# pascal_2007/train/002844.jpg
# pascal_2007/train/009250.jpg
# pascal_2007/train/003780.jpg
# pascal_2007/train/003231.jpg
# pascal_2007/train/004386.jpg
# pascal_2007/train/006588.jpg
# pascal_2007/train/005036.jpg
# pascal_2007/train/002751.jpg
# pascal_2007/train/008313.jpg
# pascal_2007/train/005789.jpg
# pascal_2007/train/000496.jpg
# pascal_2007/train/005730.jpg
# pascal_2007/train/005293.jpg
# pascal_2007/train/007559.jpg
# pascal_2007/train/002696.jpg
# pascal_2007/train/000005.jpg
# pascal_2007/train/008365.jpg
# pascal_2007/train/001754.jpg
# pascal_2007/train/003186.jpg
# pascal_2007/train/008150.jpg
# pascal_2007/train/001443.jpg
# pascal_2007/train/008856.jpg
# pascal_2007/train/000162.jpg
# pascal_2007/train/002034.jpg
# pascal_2007/train/005450.jpg
# pascal_2007/train/009420.jpg
# pascal_2007/train/000997.jpg
# pascal_2007/train/009512.jpg
# pascal_2007/train/001269.jpg
# pascal_2007/train/008576.jpg
# pascal_2007/train/009247.jpg
# pascal_2007/train/005244.jpg
# pascal_2007/train/002253.jpg
# pascal_2007/train/006748.jpg
# pascal_2007/train/002315.jpg
# pascal_2007/train/006045.jpg
# pascal_2007/train/000156.jpg
# pascal_2007/train/001766.jpg
# pascal_2007/train/003860.jpg
# pascal_2007/train/004136.jpg
# pascal_2007/train/003453.jpg
# pascal_2007/train/004524.jpg
# pascal_2007/train/003412.jpg
# pascal_2007/train/009496.jpg
# pascal_2007/train/001504.jpg
# pascal_2007/train/005378.jpg
# pascal_2007/train/003464.jpg
# pascal_2007/train/004152.jpg
# pascal_2007/train/005710.jpg
# pascal_2007/train/009805.jpg
# pascal_2007/train/000677.jpg
# pascal_2007/train/007294.jpg
# pascal_2007/train/005740.jpg
# pascal_2007/train/005039.jpg
# pascal_2007/train/001576.jpg
# pascal_2007/train/008582.jpg
# pascal_2007/train/007908.jpg
# pascal_2007/train/008326.jpg
# pascal_2007/train/008536.jpg
# pascal_2007/train/004190.jpg
# pascal_2007/train/009618.jpg
# pascal_2007/train/002704.jpg
# pascal_2007/train/008783.jpg
# pascal_2007/train/001691.jpg
# pascal_2007/train/004683.jpg
# pascal_2007/train/000233.jpg
# pascal_2007/train/005470.jpg
# pascal_2007/train/004196.jpg
# pascal_2007/train/006509.jpg
# pascal_2007/train/004221.jpg
# pascal_2007/train/005963.jpg
# pascal_2007/train/003436.jpg
# pascal_2007/train/008680.jpg
# pascal_2007/train/007721.jpg
# pascal_2007/train/001207.jpg
# pascal_2007/train/008814.jpg
# pascal_2007/train/005325.jpg
# pascal_2007/train/006150.jpg
# pascal_2007/train/000799.jpg
# pascal_2007/train/009238.jpg
# pascal_2007/train/009213.jpg
# pascal_2007/train/001793.jpg
# pascal_2007/train/009365.jpg
# pascal_2007/train/007454.jpg
# pascal_2007/train/007547.jpg
# pascal_2007/train/005760.jpg
# pascal_2007/train/007824.jpg
# pascal_2007/train/002332.jpg
# pascal_2007/train/009432.jpg
# pascal_2007/train/003956.jpg
# pascal_2007/train/005788.jpg
# pascal_2007/train/008939.jpg
# pascal_2007/train/001236.jpg
# pascal_2007/train/008750.jpg
# pascal_2007/train/003773.jpg
# pascal_2007/train/005679.jpg
# pascal_2007/train/009268.jpg
# pascal_2007/train/000020.jpg
# pascal_2007/train/007466.jpg
# pascal_2007/train/004905.jpg
# pascal_2007/train/003009.jpg
# pascal_2007/train/007438.jpg
# pascal_2007/train/001097.jpg
# pascal_2007/train/002579.jpg
# pascal_2007/train/009049.jpg
# pascal_2007/train/003129.jpg
# pascal_2007/train/004390.jpg
# pascal_2007/train/003657.jpg
# pascal_2007/train/001945.jpg
# pascal_2007/train/006501.jpg
# pascal_2007/train/007526.jpg
# pascal_2007/train/005884.jpg
# pascal_2007/train/004279.jpg
# pascal_2007/train/000814.jpg
# pascal_2007/train/003671.jpg
# pascal_2007/train/001789.jpg
# pascal_2007/train/002744.jpg
# pascal_2007/train/007527.jpg
# pascal_2007/train/007419.jpg
# pascal_2007/train/007863.jpg
# pascal_2007/train/001130.jpg
# pascal_2007/train/004966.jpg
# pascal_2007/train/004850.jpg
# pascal_2007/train/001777.jpg
# pascal_2007/train/000118.jpg
# pascal_2007/train/008310.jpg
# pascal_2007/train/005084.jpg
# pascal_2007/train/006264.jpg
# pascal_2007/train/007007.jpg
# pascal_2007/train/008667.jpg
# pascal_2007/train/007374.jpg
# pascal_2007/train/009684.jpg
# pascal_2007/train/005960.jpg
# pascal_2007/train/004215.jpg
# pascal_2007/train/003848.jpg
# pascal_2007/train/001515.jpg
# pascal_2007/train/004487.jpg
# pascal_2007/train/000520.jpg
# pascal_2007/train/002373.jpg
# pascal_2007/train/005738.jpg
# pascal_2007/train/006078.jpg
# pascal_2007/train/003855.jpg
# pascal_2007/train/002977.jpg
# pascal_2007/train/007311.jpg
# pascal_2007/train/003759.jpg
# pascal_2007/train/006236.jpg
# pascal_2007/train/006434.jpg
# pascal_2007/train/004120.jpg
# pascal_2007/train/007799.jpg
# pascal_2007/train/007417.jpg
# pascal_2007/train/008769.jpg
# pascal_2007/train/007361.jpg
# pascal_2007/train/006617.jpg
# pascal_2007/train/008965.jpg
# pascal_2007/train/002470.jpg
# pascal_2007/train/003522.jpg
# pascal_2007/train/007266.jpg
# pascal_2007/train/003254.jpg
# pascal_2007/train/007662.jpg
# pascal_2007/train/006261.jpg
# pascal_2007/train/007458.jpg
# pascal_2007/train/007031.jpg
# pascal_2007/train/004352.jpg
# pascal_2007/train/008960.jpg
# pascal_2007/train/007819.jpg
# pascal_2007/train/006377.jpg
# pascal_2007/train/008913.jpg
# pascal_2007/train/002827.jpg
# pascal_2007/train/005911.jpg
# pascal_2007/train/008117.jpg
# pascal_2007/train/005374.jpg
# pascal_2007/train/005928.jpg
# pascal_2007/train/003743.jpg
# pascal_2007/train/002255.jpg
# pascal_2007/train/001746.jpg
# pascal_2007/train/007279.jpg
# pascal_2007/train/003654.jpg
# pascal_2007/train/008355.jpg
# pascal_2007/train/008588.jpg
# pascal_2007/train/009215.jpg
# pascal_2007/train/005136.jpg
# pascal_2007/train/004105.jpg
# pascal_2007/train/006367.jpg
# pascal_2007/train/005536.jpg
# pascal_2007/train/000498.jpg
# pascal_2007/train/004405.jpg
# pascal_2007/train/000083.jpg
# pascal_2007/train/004351.jpg
# pascal_2007/train/009138.jpg
# pascal_2007/train/000219.jpg
# pascal_2007/train/007425.jpg
# pascal_2007/train/006038.jpg
# pascal_2007/train/002452.jpg
# pascal_2007/train/007021.jpg
# pascal_2007/train/005952.jpg
# pascal_2007/train/003793.jpg
# pascal_2007/train/000147.jpg
# pascal_2007/train/006285.jpg
# pascal_2007/train/008101.jpg
# pascal_2007/train/001365.jpg
# pascal_2007/train/002646.jpg
# pascal_2007/train/006352.jpg
# pascal_2007/train/000109.jpg
# pascal_2007/train/001277.jpg
# pascal_2007/train/006183.jpg
# pascal_2007/train/002083.jpg
# pascal_2007/train/001071.jpg
# pascal_2007/train/009598.jpg
# pascal_2007/train/007974.jpg
# pascal_2007/train/006023.jpg
# pascal_2007/train/005812.jpg
# pascal_2007/train/008301.jpg
# pascal_2007/train/009732.jpg
# pascal_2007/train/002693.jpg
# pascal_2007/train/001818.jpg
# pascal_2007/train/007284.jpg
# pascal_2007/train/001166.jpg
# pascal_2007/train/002699.jpg
# pascal_2007/train/007470.jpg
# pascal_2007/train/007247.jpg
# pascal_2007/train/005550.jpg
# pascal_2007/train/000712.jpg
# pascal_2007/train/007388.jpg
# pascal_2007/train/005697.jpg
# pascal_2007/train/007217.jpg
# pascal_2007/train/006437.jpg
# pascal_2007/train/001579.jpg
# pascal_2007/train/008037.jpg
# pascal_2007/train/004242.jpg
# pascal_2007/train/001091.jpg
# pascal_2007/train/004828.jpg
# pascal_2007/train/000193.jpg
# pascal_2007/train/006319.jpg
# pascal_2007/train/006682.jpg
# pascal_2007/train/008876.jpg
# pascal_2007/train/004241.jpg
# pascal_2007/train/001312.jpg
# pascal_2007/train/002690.jpg
# pascal_2007/train/002247.jpg
# pascal_2007/train/008549.jpg
# pascal_2007/train/009004.jpg
# pascal_2007/train/009128.jpg
# pascal_2007/train/006337.jpg
# pascal_2007/train/009718.jpg
# pascal_2007/train/002354.jpg
# pascal_2007/train/000477.jpg
# pascal_2007/train/003142.jpg
# pascal_2007/train/007566.jpg
# pascal_2007/train/006299.jpg
# pascal_2007/train/005485.jpg
# pascal_2007/train/004815.jpg
# pascal_2007/train/007731.jpg
# pascal_2007/train/000648.jpg
# pascal_2007/train/003420.jpg
# pascal_2007/train/008472.jpg
# pascal_2007/train/001860.jpg
# pascal_2007/train/004028.jpg
# pascal_2007/train/000336.jpg
# pascal_2007/train/001733.jpg
# pascal_2007/train/006065.jpg
# pascal_2007/train/009174.jpg
# pascal_2007/train/003337.jpg
# pascal_2007/train/000680.jpg
# pascal_2007/train/000482.jpg
# pascal_2007/train/007350.jpg
# pascal_2007/train/007383.jpg
# pascal_2007/train/003477.jpg
# pascal_2007/train/009532.jpg
# pascal_2007/train/008168.jpg
# pascal_2007/train/001807.jpg
# pascal_2007/train/005454.jpg
# pascal_2007/train/003169.jpg
# pascal_2007/train/003002.jpg
# pascal_2007/train/007536.jpg
# pascal_2007/train/007363.jpg
# pascal_2007/train/002362.jpg
# pascal_2007/train/006108.jpg
# pascal_2007/train/005311.jpg
# pascal_2007/train/001765.jpg
# pascal_2007/train/006587.jpg
# pascal_2007/train/001148.jpg
# pascal_2007/train/005603.jpg
# pascal_2007/train/003126.jpg
# pascal_2007/train/005326.jpg
# pascal_2007/train/005983.jpg
# pascal_2007/train/006610.jpg
# pascal_2007/train/002709.jpg
# pascal_2007/train/001854.jpg
# pascal_2007/train/005346.jpg
# pascal_2007/train/002393.jpg
# pascal_2007/train/001524.jpg
# pascal_2007/train/005306.jpg
# pascal_2007/train/000343.jpg
# pascal_2007/train/000026.jpg
# pascal_2007/train/003655.jpg
# pascal_2007/train/001273.jpg
# pascal_2007/train/001985.jpg
# pascal_2007/train/005686.jpg
# pascal_2007/train/009162.jpg
# pascal_2007/train/009401.jpg
# pascal_2007/train/006396.jpg
# pascal_2007/train/004429.jpg
# pascal_2007/train/007214.jpg
# pascal_2007/train/009191.jpg
# pascal_2007/train/009412.jpg
# pascal_2007/train/003145.jpg
# pascal_2007/train/006708.jpg
# pascal_2007/train/008336.jpg
# pascal_2007/train/008900.jpg
# pascal_2007/train/005647.jpg
# pascal_2007/train/002834.jpg
# pascal_2007/train/000768.jpg
# pascal_2007/train/005101.jpg
# pascal_2007/train/007071.jpg
# pascal_2007/train/002334.jpg
# pascal_2007/train/000122.jpg
# pascal_2007/train/002800.jpg
# pascal_2007/train/007605.jpg
# pascal_2007/train/009897.jpg
# pascal_2007/train/000110.jpg
# pascal_2007/train/003417.jpg
# pascal_2007/train/009872.jpg
# pascal_2007/train/000633.jpg
# pascal_2007/train/008012.jpg
# pascal_2007/train/001229.jpg
# pascal_2007/train/005852.jpg
# pascal_2007/train/009455.jpg
# pascal_2007/train/007555.jpg
# pascal_2007/train/006198.jpg
# pascal_2007/train/001136.jpg
# pascal_2007/train/002120.jpg
# pascal_2007/train/008332.jpg
# pascal_2007/train/002940.jpg
# pascal_2007/train/004783.jpg
# pascal_2007/train/007883.jpg
# pascal_2007/train/000463.jpg
# pascal_2007/train/002090.jpg
# pascal_2007/train/005190.jpg

# %%
# !ls pascal_2007
# Out:
# segmentation  test.csv	 train	    train.json
# test	      test.json  train.csv  valid.json

# %% [markdown]
# The annotations for the images are stored in json files that give the bounding boxes for each class.

# %%
path =Path('pascal_2007')

# %%
import json
annots = json.load(open(path/'train.json'))

# %%
annots.keys()
# Out:
# dict_keys(['images', 'type', 'annotations', 'categories'])

# %%
annots['annotations'][0]
# Out:
# {'area': 34104,
#  'bbox': [155, 96, 196, 174],
#  'category_id': 7,
#  'id': 1,
#  'ignore': 0,
#  'image_id': 12,
#  'iscrowd': 0,
#  'segmentation': [[155, 96, 155, 270, 351, 270, 351, 96]]}

# %% [markdown]
# This first annotation is a bounding box on the image with id 12, and the corresponding object is the category with id 7. We can read the correspondance in the 'images' and the 'categories' keys.

# %%
annots['categories']
# Out:
# [{'id': 1, 'name': 'aeroplane', 'supercategory': 'none'},
#  {'id': 2, 'name': 'bicycle', 'supercategory': 'none'},
#  {'id': 3, 'name': 'bird', 'supercategory': 'none'},
#  {'id': 4, 'name': 'boat', 'supercategory': 'none'},
#  {'id': 5, 'name': 'bottle', 'supercategory': 'none'},
#  {'id': 6, 'name': 'bus', 'supercategory': 'none'},
#  {'id': 7, 'name': 'car', 'supercategory': 'none'},
#  {'id': 8, 'name': 'cat', 'supercategory': 'none'},
#  {'id': 9, 'name': 'chair', 'supercategory': 'none'},
#  {'id': 10, 'name': 'cow', 'supercategory': 'none'},
#  {'id': 11, 'name': 'diningtable', 'supercategory': 'none'},
#  {'id': 12, 'name': 'dog', 'supercategory': 'none'},
#  {'id': 13, 'name': 'horse', 'supercategory': 'none'},
#  {'id': 14, 'name': 'motorbike', 'supercategory': 'none'},
#  {'id': 15, 'name': 'person', 'supercategory': 'none'},
#  {'id': 16, 'name': 'pottedplant', 'supercategory': 'none'},
#  {'id': 17, 'name': 'sheep', 'supercategory': 'none'},
#  {'id': 18, 'name': 'sofa', 'supercategory': 'none'},
#  {'id': 19, 'name': 'train', 'supercategory': 'none'},
#  {'id': 20, 'name': 'tvmonitor', 'supercategory': 'none'}]

# %% [markdown]
# There is a convenience method in fastai to extract all the annotations and map them with the right images/categories directly, as long as they are in the format we just saw (called the COCO format).

# %%
train_images, train_lbl_bbox = get_annotations(path/'train.json')
val_images, val_lbl_bbox = get_annotations(path/'valid.json')
#tst_images, tst_lbl_bbox = get_annotations(path/'test.json')

# %% [markdown]
# Here we will directly find the same image as before at the beginning of the training set, with the corresponding bounding box and category.

# %%
train_images[0], train_lbl_bbox[0]
# Out:
# ('000012.jpg', [[[96, 155, 270, 351]], ['car']])

# %% [markdown]
# To see it, we open the image properly and we create an `ImageBBox` object from the list of bounding boxes. This will allow us to apply data augmentation to our bounding box. To create an `ImageBBox`, we need to give it the height and the width of the original picture, the list of bounding boxes, the list of category ids and the classes list (to map an id to a class).
#
# Here we don't have a class dictionary available (that will be done automatically behind the scenes with the data block API), so we just pass id 0 and `classes=['car']`.

# %%
img = open_image(path/'train'/train_images[0])
bbox = ImageBBox.create(*img.size, train_lbl_bbox[0][0], [0], classes=['car'])
img.show(figsize=(6,4), y=bbox)

# %% [markdown]
# This works with one or several bounding boxes:

# %%
train_images[1], train_lbl_bbox[1]
# Out:
# ('000017.jpg',
#  [[[61, 184, 199, 279], [77, 89, 336, 403]], ['person', 'horse']])

# %%
img = open_image(path/'train'/train_images[1])
bbox = ImageBBox.create(*img.size, train_lbl_bbox[1][0], [0, 1], classes=['person', 'horse'])
img.show(figsize=(6,4), y=bbox)

# %% [markdown]
# And if we apply a transform to our image and the `ImageBBox` object, they stay aligned:

# %%
img = img.rotate(-10)
bbox = bbox.rotate(-10)
img.show(figsize=(6,4), y=bbox)

# %% [markdown]
# We group all the image filenames and annotations together, to use the data block API to load the dataset in a `DataBunch`.

# %%
images, lbl_bbox = train_images+val_images,train_lbl_bbox+val_lbl_bbox
img2bbox = dict(zip(images, lbl_bbox))
get_y_func = lambda o:img2bbox[o.name]

# %%
def get_data(bs, size):
    src = ObjectItemList.from_folder(path/'train')
    src = src.split_by_files(val_images)
    src = src.label_from_func(get_y_func)
    src = src.transform(get_transforms(), size=size, tfm_y=True)
    return src.databunch(path=path, bs=bs, collate_fn=bb_pad_collate)

# %%
data = get_data(64,128)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "

# %%
data.show_batch(rows=3)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/fastai/vision/data.py:361: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:882.)
#   if len((labels - self.pad_idx).nonzero()) == 0: return

# %% [markdown]
# ## Model

# %% [markdown]
# The architecture we will use is a [RetinaNet](https://arxiv.org/abs/1708.02002), which is based on a [Feature Pyramid Network](https://arxiv.org/abs/1612.03144).
#
# ![Retina net](images/retinanet.png)
#
# This is a bit like a Unet in the sense we have a branch where the image is progressively reduced then another one where we upsample it again, and there are lateral connections, but we will use the feature maps produced at each level for our final predictions. Specifically, if we start with an image of size (256,256), the traditional resnet has intermediate features maps of sizes:
# - C1 (128, 128)
# - C2 (64, 64)
# - C3 (32, 32)
# - C4 (16, 16)
# - C5 (8, 8)
# To which the authors add two other features maps C6 and C7 of sizes (4,4) and (2,2) by using stride-2 convolutions. (Note that the model requires an image size of 128 at the minimum because of this.)
#
# Then we have P7 = C7 and we go down from P7 to P2 by upsampling the result of the previous P-layer and adding a lateral connection. The idea is that the last feature map P7 will be responsible to detect big objects, while one like P3 will be responsible to detect smaller objects.
#
# Each P-something feature map then goes through two subnet of four convolutional layers (with the same weights for all the feature maps), one that will be responsible for finding the category of the object and the other for drawing the bounding box. Each location in the feature map is assigned a given number of anchors (see below) so the classifier ends up with `n_anchors * n_classes` channels and the bounding box regressor with `n_anchors * 4` channels.

# %%
#Grab the convenience functions that helps us buil the Unet
from fastai.vision.models.unet import _get_sfs_idxs, model_sizes, hook_outputs

# %%
class LateralUpsampleMerge(nn.Module):
    "Merge the features coming from the downsample path (in `hook`) with the upsample path."
    def __init__(self, ch, ch_lat, hook):
        super().__init__()
        self.hook = hook
        self.conv_lat = conv2d(ch_lat, ch, ks=1, bias=True)
    
    def forward(self, x):
        return self.conv_lat(self.hook.stored) + F.interpolate(x, self.hook.stored.shape[-2:], mode='nearest')

# %%
class RetinaNet(nn.Module):
    "Implements RetinaNet from https://arxiv.org/abs/1708.02002"
    def __init__(self, encoder:nn.Module, n_classes, final_bias=0., chs=256, n_anchors=9, flatten=True):
        super().__init__()
        self.n_classes,self.flatten = n_classes,flatten
        imsize = (256,256)
        sfs_szs = model_sizes(encoder, size=imsize)
        sfs_idxs = list(reversed(_get_sfs_idxs(sfs_szs)))
        self.sfs = hook_outputs([encoder[i] for i in sfs_idxs])
        self.encoder = encoder
        self.c5top5 = conv2d(sfs_szs[-1][1], chs, ks=1, bias=True)
        self.c5top6 = conv2d(sfs_szs[-1][1], chs, stride=2, bias=True)
        self.p6top7 = nn.Sequential(nn.ReLU(), conv2d(chs, chs, stride=2, bias=True))
        self.merges = nn.ModuleList([LateralUpsampleMerge(chs, sfs_szs[idx][1], hook) 
                                     for idx,hook in zip(sfs_idxs[-2:-4:-1], self.sfs[-2:-4:-1])])
        self.smoothers = nn.ModuleList([conv2d(chs, chs, 3, bias=True) for _ in range(3)])
        self.classifier = self._head_subnet(n_classes, n_anchors, final_bias, chs=chs)
        self.box_regressor = self._head_subnet(4, n_anchors, 0., chs=chs)
        
    def _head_subnet(self, n_classes, n_anchors, final_bias=0., n_conv=4, chs=256):
        "Helper function to create one of the subnet for regression/classification."
        layers = [conv_layer(chs, chs, bias=True, norm_type=None) for _ in range(n_conv)]
        layers += [conv2d(chs, n_classes * n_anchors, bias=True)]
        layers[-1].bias.data.zero_().add_(final_bias)
        layers[-1].weight.data.fill_(0)
        return nn.Sequential(*layers)
    
    def _apply_transpose(self, func, p_states, n_classes):
        #Final result of the classifier/regressor is bs * (k * n_anchors) * h * w
        #We make it bs * h * w * n_anchors * k then flatten in bs * -1 * k so we can contenate
        #all the results in bs * anchors * k (the non flatten version is there for debugging only)
        if not self.flatten: 
            sizes = [[p.size(0), p.size(2), p.size(3)] for p in p_states]
            return [func(p).permute(0,2,3,1).view(*sz,-1,n_classes) for p,sz in zip(p_states,sizes)]
        else:
            return torch.cat([func(p).permute(0,2,3,1).contiguous().view(p.size(0),-1,n_classes) for p in p_states],1)
    
    def forward(self, x):
        c5 = self.encoder(x)
        p_states = [self.c5top5(c5.clone()), self.c5top6(c5)]
        p_states.append(self.p6top7(p_states[-1]))
        for merge in self.merges: p_states = [merge(p_states[0])] + p_states
        for i, smooth in enumerate(self.smoothers[:3]):
            p_states[i] = smooth(p_states[i])
        return [self._apply_transpose(self.classifier, p_states, self.n_classes), 
                self._apply_transpose(self.box_regressor, p_states, 4),
                [[p.size(2), p.size(3)] for p in p_states]]
    
    def __del__(self):
        if hasattr(self, "sfs"): self.sfs.remove()

# %% [markdown]
# The model is a bit complex, but that's not the hardest part. It will spit out an absurdly high number of predictions: for the features P3 to P7 with an image size of 256, we have `32*32 + 16*16 + 8*8 + 4*4 +2*2` locations possible in one of the five feature maps, which gives 1,364 possible detections, multiplied by the number of anchors we choose to attribute to each location (9 below), which makes 12,276 possible hits.
#
# A lot of those aren't going to correspond to any object in the picture, and we need to somehow match all those predictions to either nothing or a given bounding box in the picture.

# %% [markdown]
# ## "Encore" boxes

# %% [markdown]
# If we look at the feature map of size `4*4`, we have 16 locations numbered like below:

# %%
torch.arange(0,16).long().view(4,4)

# %% [markdown]
# The most basic way to map one of these features with an actual area inside the image is to create the regular 4 by 4 grid. Our convention is that `y` is first (like in numpy or PyTorch), and that all coordinates are scaled from -1 to 1 (-1 being top/right, 1 being bottom/left).

# %%
def create_grid(size):
    "Create a grid of a given `size`."
    H, W = size if is_tuple(size) else (size,size)
    grid = FloatTensor(H, W, 2)
    linear_points = torch.linspace(-1+1/W, 1-1/W, W) if W > 1 else tensor([0.])
    grid[:, :, 1] = torch.ger(torch.ones(H), linear_points).expand_as(grid[:, :, 0])
    linear_points = torch.linspace(-1+1/H, 1-1/H, H) if H > 1 else tensor([0.])
    grid[:, :, 0] = torch.ger(linear_points, torch.ones(W)).expand_as(grid[:, :, 1])
    return grid.view(-1,2)

# %% [markdown]
# Let's use a helper function to draw those anchors:

# %%
def show_anchors(ancs, size):
    _,ax = plt.subplots(1,1, figsize=(5,5))
    ax.set_xticks(np.linspace(-1,1, size[1]+1))
    ax.set_yticks(np.linspace(-1,1, size[0]+1))
    ax.grid()
    ax.scatter(ancs[:,1], ancs[:,0]) #y is first
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.set_xlim(-1,1)
    ax.set_ylim(1,-1) #-1 is top, 1 is bottom
    for i, (x, y) in enumerate(zip(ancs[:, 1], ancs[:, 0])): ax.annotate(i, xy = (x,y))

# %%
size = (4,4)
show_anchors(create_grid(size), size)

# %% [markdown]
# In practice, we use different ratios and scales of that basic grid to build our anchors, because bounding boxes aren't always a perfect square inside a grid.

# %%
def create_anchors(sizes, ratios, scales, flatten=True):
    "Create anchor of `sizes`, `ratios` and `scales`."
    aspects = [[[s*math.sqrt(r), s*math.sqrt(1/r)] for s in scales] for r in ratios]
    aspects = torch.tensor(aspects).view(-1,2)
    anchors = []
    for h,w in sizes:
        #4 here to have the anchors overlap.
        sized_aspects = 4 * (aspects * torch.tensor([2/h,2/w])).unsqueeze(0)
        base_grid = create_grid((h,w)).unsqueeze(1)
        n,a = base_grid.size(0),aspects.size(0)
        ancs = torch.cat([base_grid.expand(n,a,2), sized_aspects.expand(n,a,2)], 2)
        anchors.append(ancs.view(h,w,a,4))
    return torch.cat([anc.view(-1,4) for anc in anchors],0) if flatten else anchors

# %%
ratios = [1/2,1,2]
scales = [1,2**(-1/3), 2**(-2/3)] 
#Paper used [1,2**(1/3), 2**(2/3)] but a bigger size (600) too, so the largest feature map gave anchors that cover less of the image.
sizes = [(2**i,2**i) for i in range(5)]
sizes.reverse() #Predictions come in the order of the smallest feature map to the biggest
anchors = create_anchors(sizes, ratios, scales)

# %%
anchors.size()

# %% [markdown]
# That's a bit less than in our computation earlier, but this is because it's for the case of (128,128) images (sizes go from (1,1) to (32,32) instead of (2,2) to (64,64)).

# %%
import matplotlib.cm as cmx
import matplotlib.colors as mcolors
from cycler import cycler

def get_cmap(N):
    color_norm  = mcolors.Normalize(vmin=0, vmax=N-1)
    return cmx.ScalarMappable(norm=color_norm, cmap='Set3').to_rgba

num_color = 12
cmap = get_cmap(num_color)
color_list = [cmap(float(x)) for x in range(num_color)]

def draw_outline(o, lw):
    o.set_path_effects([patheffects.Stroke(
        linewidth=lw, foreground='black'), patheffects.Normal()])

def draw_rect(ax, b, color='white'):
    patch = ax.add_patch(patches.Rectangle(b[:2], *b[-2:], fill=False, edgecolor=color, lw=2))
    draw_outline(patch, 4)

def draw_text(ax, xy, txt, sz=14, color='white'):
    text = ax.text(*xy, txt,
        verticalalignment='top', color=color, fontsize=sz, weight='bold')
    draw_outline(text, 1)

# %%
def show_boxes(boxes):
    "Show the `boxes` (size by 4)"
    _, ax = plt.subplots(1,1, figsize=(5,5))
    ax.set_xlim(-1,1)
    ax.set_ylim(1,-1)
    for i, bbox in enumerate(boxes):
        bb = bbox.numpy()
        rect = [bb[1]-bb[3]/2, bb[0]-bb[2]/2, bb[3], bb[2]]
        draw_rect(ax, rect, color=color_list[i%num_color])
        draw_text(ax, [bb[1]-bb[3]/2,bb[0]-bb[2]/2], str(i), color=color_list[i%num_color])

# %% [markdown]
# Here is an example of the 9 anchor boxes with different scales/ratios on one region of the image. Now imagine we have this at every location of each of the feature maps.

# %%
show_boxes(anchors[900:909])

# %% [markdown]
# For each anchor, we have one class predicted by the classifier and 4 floats `p_y,p_x,p_h,p_w` predicted by the regressor. If the corresponding anchor as a center in `anc_y`, `anc_x` with dimensions `anc_h`, `anc_w`, the predicted bounding box has those characteristics:
# ```
# center = [p_y * anc_h + anc_y, p_x * anc_w + anc_x]
# height = anc_h * exp(p_h)
# width  = anc_w * exp(p_w)
# ```
# The idea is that a prediction of `(0,0,0,0)` corresponds to the anchor itself.
#
# The next function converts the activations of the model in bounding boxes.

# %%
def activ_to_bbox(acts, anchors, flatten=True):
    "Extrapolate bounding boxes on anchors from the model activations."
    if flatten:
        acts.mul_(acts.new_tensor([[0.1, 0.1, 0.2, 0.2]])) #Can't remember where those scales come from, but they help regularize
        centers = anchors[...,2:] * acts[...,:2] + anchors[...,:2]
        sizes = anchors[...,2:] * torch.exp(acts[...,:2])
        return torch.cat([centers, sizes], -1)
    else: return [activ_to_bbox(act,anc) for act,anc in zip(acts, anchors)]
    return res

# %% [markdown]
# Here is an example with the 3 by 4 regular grid and random predictions.

# %%
size=(3,4)
anchors = create_grid(size)
anchors = torch.cat([anchors, torch.tensor([2/size[0],2/size[1]]).expand_as(anchors)], 1)
activations = torch.randn(size[0]*size[1], 4) * 0.1
bboxes = activ_to_bbox(activations, anchors)

# %%
show_boxes(bboxes)

# %% [markdown]
# This helper function changes boxes in the format center/height/width to top/left/bottom/right.

# %%
def cthw2tlbr(boxes):
    "Convert center/size format `boxes` to top/left bottom/right corners."
    top_left = boxes[:,:2] - boxes[:,2:]/2
    bot_right = boxes[:,:2] + boxes[:,2:]/2
    return torch.cat([top_left, bot_right], 1)

# %% [markdown]
# Now to decide which predicted bounding box will match a given ground truth object, we will compute the intersection over unions ratios between all the anchors and all the targets, then we will keep the ones that have an overlap greater than a given threshold (0.5).

# %%
def intersection(anchors, targets):
    "Compute the sizes of the intersections of `anchors` by `targets`."
    ancs, tgts = cthw2tlbr(anchors), cthw2tlbr(targets)
    a, t = ancs.size(0), tgts.size(0)
    ancs, tgts = ancs.unsqueeze(1).expand(a,t,4), tgts.unsqueeze(0).expand(a,t,4)
    top_left_i = torch.max(ancs[...,:2], tgts[...,:2])
    bot_right_i = torch.min(ancs[...,2:], tgts[...,2:])
    sizes = torch.clamp(bot_right_i - top_left_i, min=0) 
    return sizes[...,0] * sizes[...,1]

# %% [markdown]
# Let's see some results, if we have our 12 anchors from before...

# %%
show_boxes(anchors)

# %% [markdown]
# ... and those targets (0. is the whole image)

# %%
targets = torch.tensor([[0.,0.,2.,2.], [-0.5,-0.5,1.,1.], [1/3,0.5,0.5,0.5]])
show_boxes(targets)

# %% [markdown]
# Then the intersections of each bboxes by each targets are:

# %%
intersection(anchors, targets)

# %%
def IoU_values(anchors, targets):
    "Compute the IoU values of `anchors` by `targets`."
    inter = intersection(anchors, targets)
    anc_sz, tgt_sz = anchors[:,2] * anchors[:,3], targets[:,2] * targets[:,3]
    union = anc_sz.unsqueeze(1) + tgt_sz.unsqueeze(0) - inter
    return inter/(union+1e-8)

# %% [markdown]
# And then the IoU values are.

# %%
IoU_values(anchors, targets)

# %% [markdown]
# Then we match a anchor to targets with the following rules:
# - for each anchor we take the maximum overlap possible with any of the targets.
# - if that maximum overlap is less than 0.4, we match the anchor box to background, the classifier's target will be that class
# - if the maximum overlap is greater than 0.5, we match the anchor box to that ground truth object. The classifier's target will be the category of that target
# - if the maximum overlap is between 0.4 and 0.5, we ignore that anchor in our loss computation
# - optionally, we force-match for each ground truth object the anchor that has the maximum overlap with it (not sure it helps)

# %%
def match_anchors(anchors, targets, match_thr=0.5, bkg_thr=0.4):
    "Match `anchors` to targets. -1 is match to background, -2 is ignore."
    matches = anchors.new(anchors.size(0)).zero_().long() - 2
    if targets.numel() == 0: return matches
    ious = IoU_values(anchors, targets)
    vals,idxs = torch.max(ious,1)
    matches[vals < bkg_thr] = -1
    matches[vals > match_thr] = idxs[vals > match_thr]
    #Overwrite matches with each target getting the anchor that has the max IoU.
    #vals,idxs = torch.max(ious,0)
    #If idxs contains repetition, this doesn't bug and only the last is considered.
    #matches[idxs] = targets.new_tensor(list(range(targets.size(0)))).long()
    return matches

# %% [markdown]
# In our previous example, no one had an overlap > 0.5, so unless we use the special rule commented out, there are no matches.

# %%
match_anchors(anchors, targets)

# %% [markdown]
# With anchors very close to the targets.

# %%
size=(3,4)
anchors = create_grid(size)
anchors = torch.cat([anchors, torch.tensor([2/size[0],2/size[1]]).expand_as(anchors)], 1)
activations = 0.1 * torch.randn(size[0]*size[1], 4)
bboxes = activ_to_bbox(activations, anchors)
match_anchors(anchors,bboxes)

# %% [markdown]
# With anchors in the grey area.

# %%
anchors = create_grid((2,2))
anchors = torch.cat([anchors, torch.tensor([1.,1.]).expand_as(anchors)], 1)
targets = anchors.clone()
anchors = torch.cat([anchors, torch.tensor([[-0.5,0.,1.,1.8]])], 0)
match_anchors(anchors,targets)

# %% [markdown]
# Does the opposite of `cthw2tbr`.

# %%
def tlbr2cthw(boxes):
    "Convert top/left bottom/right format `boxes` to center/size corners."
    center = (boxes[:,:2] + boxes[:,2:])/2
    sizes = boxes[:,2:] - boxes[:,:2]
    return torch.cat([center, sizes], 1)

# %% [markdown]
# Does the opposite of `activ_to_bbox`.

# %%
def bbox_to_activ(bboxes, anchors, flatten=True):
    "Return the target of the model on `anchors` for the `bboxes`."
    if flatten:
        t_centers = (bboxes[...,:2] - anchors[...,:2]) / anchors[...,2:] 
        t_sizes = torch.log(bboxes[...,2:] / anchors[...,2:] + 1e-8) 
        return torch.cat([t_centers, t_sizes], -1).div_(bboxes.new_tensor([[0.1, 0.1, 0.2, 0.2]]))
    else: return [activ_to_bbox(act,anc) for act,anc in zip(acts, anchors)]
    return res

# %% [markdown]
# We will one-hot encode our targets with the convention that the class of index 0 is the background, which is the absence of any other classes. That is coded by a row of zeros.

# %%
def encode_class(idxs, n_classes):
    target = idxs.new_zeros(len(idxs), n_classes).float()
    mask = idxs != 0
    i1s = LongTensor(list(range(len(idxs))))
    target[i1s[mask],idxs[mask]-1] = 1
    return target

# %%
encode_class(LongTensor([1,2,0,1,3]),3)

# %% [markdown]
# And now we are ready to build the loss function. It has two parts, one for the classifier and one for the regressor. For the regression, we will use the L1 (potentially smoothed) loss between the predicted activations for an anchor that matches a given object (we ignore the no match or matches to background) and the corresponding bounding box (after going through `bbox2activ`).
#
# For the classification, we use the focal loss, which is a variant of the binary cross entropy used when we have a lot imbalance between the classes to predict (here we will very often have to predict 'background').

# %%
class RetinaNetFocalLoss(nn.Module):
    
    def __init__(self, gamma:float=2., alpha:float=0.25,  pad_idx:int=0, scales:Collection[float]=None, 
                 ratios:Collection[float]=None, reg_loss:LossFunction=F.smooth_l1_loss):
        super().__init__()
        self.gamma,self.alpha,self.pad_idx,self.reg_loss = gamma,alpha,pad_idx,reg_loss
        self.scales = ifnone(scales, [1,2**(-1/3), 2**(-2/3)])
        self.ratios = ifnone(ratios, [1/2,1,2])
        
    def _change_anchors(self, sizes:Sizes) -> bool:
        if not hasattr(self, 'sizes'): return True
        for sz1, sz2 in zip(self.sizes, sizes):
            if sz1[0] != sz2[0] or sz1[1] != sz2[1]: return True
        return False
    
    def _create_anchors(self, sizes:Sizes, device:torch.device):
        self.sizes = sizes
        self.anchors = create_anchors(sizes, self.ratios, self.scales).to(device)
    
    def _unpad(self, bbox_tgt, clas_tgt):
        i = torch.min(torch.nonzero(clas_tgt-self.pad_idx))
        return tlbr2cthw(bbox_tgt[i:]), clas_tgt[i:]-1+self.pad_idx
    
    def _focal_loss(self, clas_pred, clas_tgt):
        encoded_tgt = encode_class(clas_tgt, clas_pred.size(1))
        ps = torch.sigmoid(clas_pred.detach())
        weights = encoded_tgt * (1-ps) + (1-encoded_tgt) * ps
        alphas = (1-encoded_tgt) * self.alpha + encoded_tgt * (1-self.alpha)
        weights.pow_(self.gamma).mul_(alphas)
        clas_loss = F.binary_cross_entropy_with_logits(clas_pred, encoded_tgt, weights, reduction='sum')
        return clas_loss
        
    def _one_loss(self, clas_pred, bbox_pred, clas_tgt, bbox_tgt):
        bbox_tgt, clas_tgt = self._unpad(bbox_tgt, clas_tgt)
        matches = match_anchors(self.anchors, bbox_tgt)
        bbox_mask = matches>=0
        if bbox_mask.sum() != 0:
            bbox_pred = bbox_pred[bbox_mask]
            bbox_tgt = bbox_tgt[matches[bbox_mask]]
            bb_loss = self.reg_loss(bbox_pred, bbox_to_activ(bbox_tgt, self.anchors[bbox_mask]))
        else: bb_loss = 0.
        matches.add_(1)
        clas_tgt = clas_tgt + 1
        clas_mask = matches>=0
        clas_pred = clas_pred[clas_mask]
        clas_tgt = torch.cat([clas_tgt.new_zeros(1).long(), clas_tgt])
        clas_tgt = clas_tgt[matches[clas_mask]]
        return bb_loss + self._focal_loss(clas_pred, clas_tgt)/torch.clamp(bbox_mask.sum(), min=1.)
    
    def forward(self, output, bbox_tgts, clas_tgts):
        clas_preds, bbox_preds, sizes = output
        if self._change_anchors(sizes): self._create_anchors(sizes, clas_preds.device)
        n_classes = clas_preds.size(2)
        return sum([self._one_loss(cp, bp, ct, bt)
                    for (cp, bp, ct, bt) in zip(clas_preds, bbox_preds, clas_tgts, bbox_tgts)])/clas_tgts.size(0)

# %% [markdown]
# This is a variant of the L1 loss used in several implementations:

# %%
class SigmaL1SmoothLoss(nn.Module):

    def forward(self, output, target):
        reg_diff = torch.abs(target - output)
        reg_loss = torch.where(torch.le(reg_diff, 1/9), 4.5 * torch.pow(reg_diff, 2), reg_diff - 1/18)
        return reg_loss.mean()

# %% [markdown]
# ## Defining the Learner

# %%
ratios = [1/2,1,2]
scales = [1,2**(-1/3), 2**(-2/3)]
#scales = [1,2**(1/3), 2**(2/3)] for bigger size

# %%
encoder = create_body(models.resnet50, cut=-2)
model = RetinaNet(encoder, data.c, final_bias=-4)
crit = RetinaNetFocalLoss(scales=scales, ratios=ratios)
learn = Learner(data, model, loss_func=crit)

# %% [markdown]
# Why `final_bias=-4`? That's because we want the network to predict background easily at the beginning (since it's the most common class). At first the final convolution of the classifier is initialized with weights=0 and that bias, so it will return -4 for everyone. If go though a sigmoid

# %%
torch.sigmoid(tensor([-4.]))

# %% [markdown]
# We see it'll give a corresponding probability of 0.02 roughly.
#
# Then, for transfer learning/discriminative LRs, we need to define how to split between body and custom head.

# %%
def retina_net_split(model):
    groups = [list(model.encoder.children())[:6], list(model.encoder.children())[6:]]
    return groups + [list(model.children())[1:]]

# %%
learn = learn.split(retina_net_split)

# %% [markdown]
# And now we can train as usual!

# %%
learn.freeze()

# %%
learn.lr_find()

# %%
learn.recorder.plot(skip_end=5)

# %%
learn.fit_one_cycle(5, 1e-4)

# %%
learn.save('stage1-128')

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(10, slice(1e-6, 5e-5))

# %%
learn.save('stage2-128')

# %%
learn.data = get_data(32,192)

# %%
learn.freeze()
learn.lr_find()

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(5, 1e-4)

# %%
learn.save('stage1-192')

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(10, slice(1e-6, 5e-5))

# %%
learn.save('stage2-192')

# %%
learn.data = get_data(24,256)

# %%
learn.freeze()
learn.fit_one_cycle(5, 1e-4)

# %%
learn.save('stage1-256')

# %%
learn.unfreeze()
learn.fit_one_cycle(10, slice(1e-6, 5e-5))

# %%
learn.save('stage2-256')

# %% [markdown]
# ## Results

# %%
learn = learn.load('stage2-256')

# %%
img,target = next(iter(data.valid_dl))
with torch.no_grad():
    output = learn.model(img)

# %% [markdown]
# First we need to remove the padding that was added to collate our targets together.

# %%
def unpad(tgt_bbox, tgt_clas, pad_idx=0):
    i = torch.min(torch.nonzero(tgt_clas-pad_idx))
    return tlbr2cthw(tgt_bbox[i:]), tgt_clas[i:]-1+pad_idx

# %% [markdown]
# Then we process the outputs of the model: we convert the activations of the regressor to bounding boxes and the predictions to probabilities, only keeping those above a given threshold.

# %%
def process_output(output, i, detect_thresh=0.25):
    "Process `output[i]` and return the predicted bboxes above `detect_thresh`."
    clas_pred,bbox_pred,sizes = output[0][i], output[1][i], output[2]
    anchors = create_anchors(sizes, ratios, scales).to(clas_pred.device)
    bbox_pred = activ_to_bbox(bbox_pred, anchors)
    clas_pred = torch.sigmoid(clas_pred)
    detect_mask = clas_pred.max(1)[0] > detect_thresh
    bbox_pred, clas_pred = bbox_pred[detect_mask], clas_pred[detect_mask]
    bbox_pred = tlbr2cthw(torch.clamp(cthw2tlbr(bbox_pred), min=-1, max=1))    
    scores, preds = clas_pred.max(1)
    return bbox_pred, scores, preds

# %% [markdown]
# Helper functions to plot the results

# %%
def _draw_outline(o:Patch, lw:int):
    "Outline bounding box onto image `Patch`."
    o.set_path_effects([patheffects.Stroke(
        linewidth=lw, foreground='black'), patheffects.Normal()])

def draw_rect(ax:plt.Axes, b:Collection[int], color:str='white', text=None, text_size=14):
    "Draw bounding box on `ax`."
    patch = ax.add_patch(patches.Rectangle(b[:2], *b[-2:], fill=False, edgecolor=color, lw=2))
    _draw_outline(patch, 4)
    if text is not None:
        patch = ax.text(*b[:2], text, verticalalignment='top', color=color, fontsize=text_size, weight='bold')
        _draw_outline(patch,1)

# %%
def show_preds(img, output, idx, detect_thresh=0.25, classes=None):
    bbox_pred, scores, preds = process_output(output, idx, detect_thresh)
    bbox_pred, preds, scores = bbox_pred.cpu(), preds.cpu(), scores.cpu()
    t_sz = torch.Tensor([*img.size])[None].float()
    bbox_pred[:,:2] = bbox_pred[:,:2] - bbox_pred[:,2:]/2
    bbox_pred[:,:2] = (bbox_pred[:,:2] + 1) * t_sz/2
    bbox_pred[:,2:] = bbox_pred[:,2:] * t_sz
    bbox_pred = bbox_pred.long()
    _, ax = plt.subplots(1,1)
    for bbox, c, scr in zip(bbox_pred, preds, scores):
        img.show(ax=ax)
        txt = str(c.item()) if classes is None else classes[c.item()+1]
        draw_rect(ax, [bbox[1],bbox[0],bbox[3],bbox[2]], text=f'{txt} {scr:.2f}')

# %% [markdown]
# And let's have a look at one picture.

# %%
idx = 0
img = data.valid_ds[idx][0]
show_preds(img, output, idx, detect_thresh=0.3, classes=data.classes)

# %% [markdown]
# It looks like a lot of our anchors are detecting kind of the same object. We use an algorithm called Non-Maximum Suppression to remove near-duplicates: going from the biggest score predicted to the lowest, we take the corresponding bounding boxes and remove all the bounding boxes down the list that have an IoU > 0.5 with this one. We continue the process until we have reached the end of the list.

# %%
def nms(boxes, scores, thresh=0.3):
    idx_sort = scores.argsort(descending=True)
    boxes, scores = boxes[idx_sort], scores[idx_sort]
    to_keep, indexes = [], torch.LongTensor(range_of(scores))
    while len(scores) > 0:
        to_keep.append(idx_sort[indexes[0]])
        iou_vals = IoU_values(boxes, boxes[:1]).squeeze()
        mask_keep = iou_vals < thresh
        if len(mask_keep.nonzero()) == 0: break
        boxes, scores, indexes = boxes[mask_keep], scores[mask_keep], indexes[mask_keep]
    return LongTensor(to_keep)

# %%
def process_output(output, i, detect_thresh=0.25):
    clas_pred,bbox_pred,sizes = output[0][i], output[1][i], output[2]
    anchors = create_anchors(sizes, ratios, scales).to(clas_pred.device)
    bbox_pred = activ_to_bbox(bbox_pred, anchors)
    clas_pred = torch.sigmoid(clas_pred)
    detect_mask = clas_pred.max(1)[0] > detect_thresh
    bbox_pred, clas_pred = bbox_pred[detect_mask], clas_pred[detect_mask]
    bbox_pred = tlbr2cthw(torch.clamp(cthw2tlbr(bbox_pred), min=-1, max=1))    
    if clas_pred.numel() == 0: return [],[],[]
    scores, preds = clas_pred.max(1)
    return bbox_pred, scores, preds

# %%
def show_preds(img, output, idx, detect_thresh=0.25, classes=None, ax=None):
    bbox_pred, scores, preds = process_output(output, idx, detect_thresh)
    if len(scores) != 0:
        to_keep = nms(bbox_pred, scores)
        bbox_pred, preds, scores = bbox_pred[to_keep].cpu(), preds[to_keep].cpu(), scores[to_keep].cpu()
        t_sz = torch.Tensor([*img.size])[None].float()
        bbox_pred[:,:2] = bbox_pred[:,:2] - bbox_pred[:,2:]/2
        bbox_pred[:,:2] = (bbox_pred[:,:2] + 1) * t_sz/2
        bbox_pred[:,2:] = bbox_pred[:,2:] * t_sz
        bbox_pred = bbox_pred.long()
    if ax is None: _, ax = plt.subplots(1,1)
    img.show(ax=ax)
    for bbox, c, scr in zip(bbox_pred, preds, scores):
        txt = str(c.item()) if classes is None else classes[c.item()+1]
        draw_rect(ax, [bbox[1],bbox[0],bbox[3],bbox[2]], text=f'{txt} {scr:.2f}')

# %%
def show_results(learn, start=0, n=5, detect_thresh=0.35, figsize=(10,25)):
    x,y = learn.data.one_batch(DatasetType.Valid, cpu=False)
    with torch.no_grad():
        z = learn.model.eval()(x)
    _,axs = plt.subplots(n, 2, figsize=figsize)
    for i in range(n):
        img,bbox = learn.data.valid_ds[start+i]
        img.show(ax=axs[i,0], y=bbox)
        show_preds(img, z, start+i, detect_thresh=detect_thresh, classes=learn.data.classes, ax=axs[i,1])

# %%
learn = learn.load('stage2-256')

# %%
show_results(learn, start=10)

# %% [markdown]
# ## mAP

# %% [markdown]
# A metric often used for this kind of task is the mean Average Precision (our mAP). It relies on computing the cumulated precision and recall for each class, then tries to compute the area under the precision/recall curve we can draw.

# %%
def get_predictions(output, idx, detect_thresh=0.05):
    bbox_pred, scores, preds = process_output(output, idx, detect_thresh)
    if len(scores) == 0: return [],[],[]
    to_keep = nms(bbox_pred, scores)
    return bbox_pred[to_keep], preds[to_keep], scores[to_keep]

# %%
def compute_ap(precision, recall):
    "Compute the average precision for `precision` and `recall` curve."
    recall = np.concatenate(([0.], list(recall), [1.]))
    precision = np.concatenate(([0.], list(precision), [0.]))
    for i in range(len(precision) - 1, 0, -1):
        precision[i - 1] = np.maximum(precision[i - 1], precision[i])
    idx = np.where(recall[1:] != recall[:-1])[0]
    ap = np.sum((recall[idx + 1] - recall[idx]) * precision[idx + 1])
    return ap

# %%
def compute_class_AP(model, dl, n_classes, iou_thresh=0.5, detect_thresh=0.35, num_keep=100):
    tps, clas, p_scores = [], [], []
    classes, n_gts = LongTensor(range(n_classes)),torch.zeros(n_classes).long()
    with torch.no_grad():
        for input,target in progress_bar(dl):
            output = model(input)
            for i in range(target[0].size(0)):
                bbox_pred, preds, scores = get_predictions(output, i, detect_thresh)
                tgt_bbox, tgt_clas = unpad(target[0][i], target[1][i])
                if len(bbox_pred) != 0 and len(tgt_bbox) != 0:
                    ious = IoU_values(bbox_pred, tgt_bbox)
                    max_iou, matches = ious.max(1)
                    detected = []
                    for i in range_of(preds):
                        if max_iou[i] >= iou_thresh and matches[i] not in detected and tgt_clas[matches[i]] == preds[i]:
                            detected.append(matches[i])
                            tps.append(1)
                        else: tps.append(0)
                    clas.append(preds.cpu())
                    p_scores.append(scores.cpu())
                n_gts += (tgt_clas.cpu()[:,None] == classes[None,:]).sum(0)
    tps, p_scores, clas = torch.tensor(tps), torch.cat(p_scores,0), torch.cat(clas,0)
    fps = 1-tps
    idx = p_scores.argsort(descending=True)
    tps, fps, clas = tps[idx], fps[idx], clas[idx]
    aps = []
    #return tps, clas
    for cls in range(n_classes):
        tps_cls, fps_cls = tps[clas==cls].float().cumsum(0), fps[clas==cls].float().cumsum(0)
        if tps_cls.numel() != 0 and tps_cls[-1] != 0:
            precision = tps_cls / (tps_cls + fps_cls + 1e-8)
            recall = tps_cls / (n_gts[cls] + 1e-8)
            aps.append(compute_ap(precision, recall))
        else: aps.append(0.)
    return aps

# %%
L = compute_class_AP(learn.model, data.valid_dl, data.c-1)

# %%
for ap,cl in zip(L, data.classes[1:]): print(f'{cl}: {ap:.6f}')

# %%
for ap,cl in zip(L, data.classes[1:]): print(f'{cl}: {ap:.6f}')

# %%
for ap,cl in zip(L, data.classes[1:]): print(f'{cl}: {ap:.6f}')

# %%
for ap,cl in zip(L, data.classes[1:]): print(f'{cl}: {ap:.6f}')

# %%
for ap,cl in zip(L, data.classes[1:]): print(f'{cl}: {ap:.6f}')
